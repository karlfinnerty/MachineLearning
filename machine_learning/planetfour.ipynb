# %% [markdown]
# ## Planet four image classification

# %%
# !tar -xvf  '/content/gdrive/MyDrive/EE514(Data-Analysis-&-Machine-Learning)/data/PlanetFour/planetfour.tar' -C '/content/gdrive/MyDrive/EE514(Data-Analysis-&-Machine-Learning)/data/PlanetFour/split/'
# Out:
# Streaming output truncated to the last 5000 lines.
# planetfour/test/APF0000st7.jpg
# planetfour/test/APF0000pvc.jpg
# planetfour/test/APF0000k67.jpg
# planetfour/test/APF00006kf.jpg
# planetfour/test/APF0000kb3.jpg
# planetfour/test/APF0000vc8.jpg
# planetfour/test/APF0000tif.jpg
# planetfour/test/APF0000dmm.jpg
# planetfour/test/APF00000pz.jpg
# planetfour/test/APF0000jde.jpg
# planetfour/test/APF0000frq.jpg
# planetfour/test/APF000056k.jpg
# planetfour/test/APF00007rd.jpg
# planetfour/test/APF0000jy6.jpg
# planetfour/test/APF00009e6.jpg
# planetfour/test/APF0000fnw.jpg
# planetfour/test/APF00000bw.jpg
# planetfour/test/APF0000cox.jpg
# planetfour/test/APF00005iu.jpg
# planetfour/test/APF0000i4k.jpg
# planetfour/test/APF00004b1.jpg
# planetfour/test/APF0000qkg.jpg
# planetfour/test/APF000080p.jpg
# planetfour/test/APF0000kxl.jpg
# planetfour/test/APF0000kd1.jpg
# planetfour/test/APF0000ivh.jpg
# planetfour/test/APF00006mz.jpg
# planetfour/test/APF0000ffs.jpg
# planetfour/test/APF0000wpl.jpg
# planetfour/test/APF00002vv.jpg
# planetfour/test/APF0000b7p.jpg
# planetfour/test/APF0000ilx.jpg
# planetfour/test/APF0000gwh.jpg
# planetfour/test/APF0000w6v.jpg
# planetfour/test/APF0000a76.jpg
# planetfour/test/APF0000p32.jpg
# planetfour/test/APF0000623.jpg
# planetfour/test/APF0000k10.jpg
# planetfour/test/APF0000ca2.jpg
# planetfour/test/APF0000dat.jpg
# planetfour/test/APF0000jke.jpg
# planetfour/test/APF0000nne.jpg
# planetfour/test/APF0000qdm.jpg
# planetfour/test/APF0000kzd.jpg
# planetfour/test/APF0000kfj.jpg
# planetfour/test/APF0000qaw.jpg
# planetfour/test/APF0000wui.jpg
# planetfour/test/APF0000cmq.jpg
# planetfour/test/APF0000v7u.jpg
# planetfour/test/APF0000h04.jpg
# planetfour/test/APF0000j6c.jpg
# planetfour/test/APF0000pfv.jpg
# planetfour/test/APF0000rxk.jpg
# planetfour/test/APF0000cqv.jpg
# planetfour/test/APF0000gnm.jpg
# planetfour/test/APF0000gkd.jpg
# planetfour/test/APF00004xu.jpg
# planetfour/test/APF0000pgj.jpg
# planetfour/test/APF0000bzs.jpg
# planetfour/test/APF0000a13.jpg
# planetfour/test/APF0000wjf.jpg
# planetfour/test/APF000093i.jpg
# planetfour/test/APF00005te.jpg
# planetfour/test/APF0000kvr.jpg
# planetfour/test/APF0000p6m.jpg
# planetfour/test/APF0000aiq.jpg
# planetfour/test/APF0000mg4.jpg
# planetfour/test/APF00001el.jpg
# planetfour/test/APF0000cuz.jpg
# planetfour/test/APF0000c9u.jpg
# planetfour/test/APF0000o7g.jpg
# planetfour/test/APF00000jo.jpg
# planetfour/test/APF0000cxf.jpg
# planetfour/test/APF00000z6.jpg
# planetfour/test/APF0000hwb.jpg
# planetfour/test/APF0000aaw.jpg
# planetfour/test/APF0000cwk.jpg
# planetfour/test/APF0000cgf.jpg
# planetfour/test/APF0000b01.jpg
# planetfour/test/APF0000ud5.jpg
# planetfour/test/APF0000lzf.jpg
# planetfour/test/APF00005z9.jpg
# planetfour/test/APF0000owi.jpg
# planetfour/test/APF00009sq.jpg
# planetfour/test/APF0000q8q.jpg
# planetfour/test/APF000093u.jpg
# planetfour/test/APF00001hw.jpg
# planetfour/test/APF0000vcf.jpg
# planetfour/test/APF00003nd.jpg
# planetfour/test/APF0000hsf.jpg
# planetfour/test/APF0000mmu.jpg
# planetfour/test/APF00005p5.jpg
# planetfour/test/APF0000exv.jpg
# planetfour/test/APF000087y.jpg
# planetfour/test/APF00006nz.jpg
# planetfour/test/APF0000ije.jpg
# planetfour/test/APF0000snu.jpg
# planetfour/test/APF0000vzj.jpg
# planetfour/test/APF0000qep.jpg
# planetfour/test/APF0000gmb.jpg
# planetfour/test/APF0000wtm.jpg
# planetfour/test/APF000050p.jpg
# planetfour/test/APF0000iea.jpg
# planetfour/test/APF0000w2y.jpg
# planetfour/test/APF0000brg.jpg
# planetfour/test/APF00006jt.jpg
# planetfour/test/APF00005oa.jpg
# planetfour/test/APF0000krv.jpg
# planetfour/test/APF0000tvs.jpg
# planetfour/test/APF00000fp.jpg
# planetfour/test/APF0000b4m.jpg
# planetfour/test/APF0000nkq.jpg
# planetfour/test/APF0000jry.jpg
# planetfour/test/APF0000jq9.jpg
# planetfour/test/APF0000t3r.jpg
# planetfour/test/APF0000vwt.jpg
# planetfour/test/APF0000gst.jpg
# planetfour/test/APF0000650.jpg
# planetfour/test/APF00001cw.jpg
# planetfour/test/APF0000hwm.jpg
# planetfour/test/APF0000brn.jpg
# planetfour/test/APF0000qmd.jpg
# planetfour/test/APF0000iw1.jpg
# planetfour/test/APF0000vin.jpg
# planetfour/test/APF00008r2.jpg
# planetfour/test/APF00003kt.jpg
# planetfour/test/APF0000r3z.jpg
# planetfour/test/APF0000icw.jpg
# planetfour/test/APF0000ke0.jpg
# planetfour/test/APF000087l.jpg
# planetfour/test/APF0000oyh.jpg
# planetfour/test/APF000034b.jpg
# planetfour/test/APF0000hyg.jpg
# planetfour/test/APF0000jja.jpg
# planetfour/test/APF0000b6i.jpg
# planetfour/test/APF000062r.jpg
# planetfour/test/APF0000fhp.jpg
# planetfour/test/APF0000ecr.jpg
# planetfour/test/APF0000ub5.jpg
# planetfour/test/APF0000ifx.jpg
# planetfour/test/APF0000ha1.jpg
# planetfour/test/APF0000bks.jpg
# planetfour/test/APF00008la.jpg
# planetfour/test/APF0000u9r.jpg
# planetfour/test/APF0000i61.jpg
# planetfour/test/APF0000t4r.jpg
# planetfour/test/APF0000kzn.jpg
# planetfour/test/APF0000r3j.jpg
# planetfour/test/APF00000d0.jpg
# planetfour/test/APF0000w57.jpg
# planetfour/test/APF0000nb8.jpg
# planetfour/test/APF00005xh.jpg
# planetfour/test/APF0000k98.jpg
# planetfour/test/APF00009ru.jpg
# planetfour/test/APF0000dj4.jpg
# planetfour/test/APF0000p3d.jpg
# planetfour/test/APF000097m.jpg
# planetfour/test/APF0000ou6.jpg
# planetfour/test/APF0000jqt.jpg
# planetfour/test/APF0000ipr.jpg
# planetfour/test/APF000065f.jpg
# planetfour/test/APF0000tog.jpg
# planetfour/test/APF0000l03.jpg
# planetfour/test/APF0000rl7.jpg
# planetfour/test/APF0000hz7.jpg
# planetfour/test/APF0000ja0.jpg
# planetfour/test/APF0000g1a.jpg
# planetfour/test/APF0000a8w.jpg
# planetfour/test/APF00008gs.jpg
# planetfour/test/APF00009gp.jpg
# planetfour/test/APF0000slu.jpg
# planetfour/test/APF0000i41.jpg
# planetfour/test/APF00008p1.jpg
# planetfour/test/APF0000kwc.jpg
# planetfour/test/APF0000c33.jpg
# planetfour/test/APF0000jmg.jpg
# planetfour/test/APF0000b5l.jpg
# planetfour/test/APF00005k6.jpg
# planetfour/test/APF00000qi.jpg
# planetfour/test/APF0000epi.jpg
# planetfour/test/APF0000ij9.jpg
# planetfour/test/APF0000kxr.jpg
# planetfour/test/APF0000lha.jpg
# planetfour/test/APF00006j7.jpg
# planetfour/test/APF000033d.jpg
# planetfour/test/APF0000e1x.jpg
# planetfour/test/APF0000tcu.jpg
# planetfour/test/APF0000l1k.jpg
# planetfour/test/APF0000gv6.jpg
# planetfour/test/APF0000e2k.jpg
# planetfour/test/APF00005z8.jpg
# planetfour/test/APF00006rj.jpg
# planetfour/test/APF00005lp.jpg
# planetfour/test/APF0000cow.jpg
# planetfour/test/APF000082o.jpg
# planetfour/test/APF00005vz.jpg
# planetfour/test/APF00000yr.jpg
# planetfour/test/APF0000r6a.jpg
# planetfour/test/APF0000l1r.jpg
# planetfour/test/APF0000n0o.jpg
# planetfour/test/APF0000n2p.jpg
# planetfour/test/APF0000ron.jpg
# planetfour/test/APF0000lx6.jpg
# planetfour/test/APF0000clo.jpg
# planetfour/test/APF0000wai.jpg
# planetfour/test/APF0000ms7.jpg
# planetfour/test/APF0000dwu.jpg
# planetfour/test/APF0000wp7.jpg
# planetfour/test/APF0000fsz.jpg
# planetfour/test/APF00009p7.jpg
# planetfour/test/APF0000a0r.jpg
# planetfour/test/APF000017a.jpg
# planetfour/test/APF00007rf.jpg
# planetfour/test/APF0000dmw.jpg
# planetfour/test/APF0000otx.jpg
# planetfour/test/APF0000klr.jpg
# planetfour/test/APF0000mms.jpg
# planetfour/test/APF0000wh2.jpg
# planetfour/test/APF0000uef.jpg
# planetfour/test/APF0000cm0.jpg
# planetfour/test/APF0000j79.jpg
# planetfour/test/APF0000790.jpg
# planetfour/test/APF0000cr9.jpg
# planetfour/test/APF0000kjy.jpg
# planetfour/test/APF0000g38.jpg
# planetfour/test/APF0000hsw.jpg
# planetfour/test/APF0000v8x.jpg
# planetfour/test/APF0000k8n.jpg
# planetfour/test/APF0000anh.jpg
# planetfour/test/APF0000ddd.jpg
# planetfour/test/APF00003h0.jpg
# planetfour/test/APF000079h.jpg
# planetfour/test/APF00002w5.jpg
# planetfour/test/APF00009a2.jpg
# planetfour/test/APF0000my2.jpg
# planetfour/test/APF0000pc9.jpg
# planetfour/test/APF0000wjz.jpg
# planetfour/test/APF000095q.jpg
# planetfour/test/APF00008s8.jpg
# planetfour/test/APF0000e6b.jpg
# planetfour/test/APF0000gx3.jpg
# planetfour/test/APF0000ugj.jpg
# planetfour/test/APF0000pvj.jpg
# planetfour/test/APF0000igr.jpg
# planetfour/test/APF0000jdy.jpg
# planetfour/test/APF0000mx1.jpg
# planetfour/test/APF00002zv.jpg
# planetfour/test/APF0000eis.jpg
# planetfour/test/APF0000a6b.jpg
# planetfour/test/APF0000avc.jpg
# planetfour/test/APF0000w0i.jpg
# planetfour/test/APF00002bp.jpg
# planetfour/test/APF0000qhl.jpg
# planetfour/test/APF0000vy8.jpg
# planetfour/test/APF0000kfk.jpg
# planetfour/test/APF00004b2.jpg
# planetfour/test/APF0000hto.jpg
# planetfour/test/APF0000by9.jpg
# planetfour/test/APF0000p7o.jpg
# planetfour/test/APF0000pj9.jpg
# planetfour/test/APF0000e69.jpg
# planetfour/test/APF000059t.jpg
# planetfour/test/APF0000pn7.jpg
# planetfour/test/APF0000crb.jpg
# planetfour/test/APF0000isu.jpg
# planetfour/test/APF0000qe8.jpg
# planetfour/test/APF0000ukc.jpg
# planetfour/test/APF0000ce7.jpg
# planetfour/test/APF0000299.jpg
# planetfour/test/APF0000jqf.jpg
# planetfour/test/APF0000m6c.jpg
# planetfour/test/APF0000su0.jpg
# planetfour/test/APF0000p5r.jpg
# planetfour/test/APF00005u0.jpg
# planetfour/test/APF00005mz.jpg
# planetfour/test/APF00003mf.jpg
# planetfour/test/APF0000boc.jpg
# planetfour/test/APF00007h4.jpg
# planetfour/test/APF0000l1y.jpg
# planetfour/test/APF00001pw.jpg
# planetfour/test/APF0000r6c.jpg
# planetfour/test/APF0000iqz.jpg
# planetfour/test/APF0000azh.jpg
# planetfour/test/APF0000aod.jpg
# planetfour/test/APF0000mx0.jpg
# planetfour/test/APF0000br3.jpg
# planetfour/test/APF0000aaz.jpg
# planetfour/test/APF00002kp.jpg
# planetfour/test/APF0000s0g.jpg
# planetfour/test/APF0000fal.jpg
# planetfour/test/APF0000bbj.jpg
# planetfour/test/APF00009r9.jpg
# planetfour/test/APF0000ew8.jpg
# planetfour/test/APF00000gm.jpg
# planetfour/test/APF0000i0a.jpg
# planetfour/test/APF0000kqu.jpg
# planetfour/test/APF00007c2.jpg
# planetfour/test/APF0000bc7.jpg
# planetfour/test/APF00006yw.jpg
# planetfour/test/APF0000hvg.jpg
# planetfour/test/APF0000waa.jpg
# planetfour/test/APF0000chb.jpg
# planetfour/test/APF000030v.jpg
# planetfour/test/APF0000r52.jpg
# planetfour/test/APF0000hpu.jpg
# planetfour/test/APF0000kuz.jpg
# planetfour/test/APF0000n5m.jpg
# planetfour/test/APF0000itc.jpg
# planetfour/test/APF0000f7t.jpg
# planetfour/test/APF00006z0.jpg
# planetfour/test/APF0000vba.jpg
# planetfour/test/APF0000ufo.jpg
# planetfour/test/APF0000o6y.jpg
# planetfour/test/APF0000l2m.jpg
# planetfour/test/APF0000st5.jpg
# planetfour/test/APF0000gpk.jpg
# planetfour/test/APF0000tbe.jpg
# planetfour/test/APF0000odo.jpg
# planetfour/test/APF0000797.jpg
# planetfour/test/APF00005qo.jpg
# planetfour/test/APF0000q7z.jpg
# planetfour/test/APF0000kex.jpg
# planetfour/test/APF0000473.jpg
# planetfour/test/APF0000ask.jpg
# planetfour/test/APF0000rno.jpg
# planetfour/test/APF0000sr3.jpg
# planetfour/test/APF0000vy3.jpg
# planetfour/test/APF0000hqk.jpg
# planetfour/test/APF0000qx8.jpg
# planetfour/test/APF000070k.jpg
# planetfour/test/APF0000c9i.jpg
# planetfour/test/APF0000qyj.jpg
# planetfour/test/APF00002s7.jpg
# planetfour/test/APF00001xj.jpg
# planetfour/test/APF0000tmo.jpg
# planetfour/test/APF0000kxs.jpg
# planetfour/test/APF0000rzp.jpg
# planetfour/test/APF0000gp0.jpg
# planetfour/test/APF0000d48.jpg
# planetfour/test/APF000019l.jpg
# planetfour/test/APF00006ud.jpg
# planetfour/test/APF00000j7.jpg
# planetfour/test/APF0000obs.jpg
# planetfour/test/APF00006ek.jpg
# planetfour/test/APF00004me.jpg
# planetfour/test/APF0000vik.jpg
# planetfour/test/APF0000406.jpg
# planetfour/test/APF0000il2.jpg
# planetfour/test/APF000085k.jpg
# planetfour/test/APF0000tg1.jpg
# planetfour/test/APF000009k.jpg
# planetfour/test/APF00006fh.jpg
# planetfour/test/APF00007dq.jpg
# planetfour/test/APF00003s0.jpg
# planetfour/test/APF000064h.jpg
# planetfour/test/APF0000kj3.jpg
# planetfour/test/APF0000gno.jpg
# planetfour/test/APF0000amc.jpg
# planetfour/test/APF00008fw.jpg
# planetfour/test/APF000090p.jpg
# planetfour/test/APF0000buo.jpg
# planetfour/test/APF00005sj.jpg
# planetfour/test/APF0000vlw.jpg
# planetfour/test/APF0000dpl.jpg
# planetfour/test/APF00002ls.jpg
# planetfour/test/APF00007h9.jpg
# planetfour/test/APF0000pvn.jpg
# planetfour/test/APF0000n3c.jpg
# planetfour/test/APF0000i3o.jpg
# planetfour/test/APF0000bn1.jpg
# planetfour/test/APF0000gpw.jpg
# planetfour/test/APF000014s.jpg
# planetfour/test/APF0000ndc.jpg
# planetfour/test/APF0000b3m.jpg
# planetfour/test/APF0000efo.jpg
# planetfour/test/APF0000t62.jpg
# planetfour/test/APF0000h1y.jpg
# planetfour/test/APF0000kd9.jpg
# planetfour/test/APF0000knx.jpg
# planetfour/test/APF0000h6l.jpg
# planetfour/test/APF0000r0v.jpg
# planetfour/test/APF0000vts.jpg
# planetfour/test/APF0000k7v.jpg
# planetfour/test/APF0000nrs.jpg
# planetfour/test/APF000093y.jpg
# planetfour/test/APF00003wu.jpg
# planetfour/test/APF0000ag9.jpg
# planetfour/test/APF0000qcd.jpg
# planetfour/test/APF0000mz2.jpg
# planetfour/test/APF000097r.jpg
# planetfour/test/APF000015w.jpg
# planetfour/test/APF0000had.jpg
# planetfour/test/APF00001qe.jpg
# planetfour/test/APF0000ssr.jpg
# planetfour/test/APF0000fcx.jpg
# planetfour/test/APF0000je3.jpg
# planetfour/test/APF0000a3k.jpg
# planetfour/test/APF0000gyd.jpg
# planetfour/test/APF0000qfp.jpg
# planetfour/test/APF0000jdq.jpg
# planetfour/test/APF0000pjj.jpg
# planetfour/test/APF00004bg.jpg
# planetfour/test/APF0000miu.jpg
# planetfour/test/APF0000k5c.jpg
# planetfour/test/APF0000655.jpg
# planetfour/test/APF0000vrr.jpg
# planetfour/test/APF00000iz.jpg
# planetfour/test/APF0000mxz.jpg
# planetfour/test/APF0000fyv.jpg
# planetfour/test/APF0000bk7.jpg
# planetfour/test/APF0000qi1.jpg
# planetfour/test/APF0000qj4.jpg
# planetfour/test/APF0000782.jpg
# planetfour/test/APF0000vco.jpg
# planetfour/test/APF0000g2s.jpg
# planetfour/test/APF0000ck6.jpg
# planetfour/test/APF00009ji.jpg
# planetfour/test/APF0000w4k.jpg
# planetfour/test/APF0000etk.jpg
# planetfour/test/APF0000ske.jpg
# planetfour/test/APF00003pw.jpg
# planetfour/test/APF0000fvn.jpg
# planetfour/test/APF00009m7.jpg
# planetfour/test/APF0000faa.jpg
# planetfour/test/APF0000bjb.jpg
# planetfour/test/APF00003ip.jpg
# planetfour/test/APF0000ab8.jpg
# planetfour/test/APF0000m2a.jpg
# planetfour/test/APF0000jmo.jpg
# planetfour/test/APF0000gny.jpg
# planetfour/test/APF000091e.jpg
# planetfour/test/APF00006n6.jpg
# planetfour/test/APF0000ltj.jpg
# planetfour/test/APF0000ewy.jpg
# planetfour/test/APF0000avz.jpg
# planetfour/test/APF0000c1i.jpg
# planetfour/test/APF0000qfr.jpg
# planetfour/test/APF00004eu.jpg
# planetfour/test/APF0000kh7.jpg
# planetfour/test/APF00005p4.jpg
# planetfour/test/APF0000jb3.jpg
# planetfour/test/APF00001z4.jpg
# planetfour/test/APF0000goj.jpg
# planetfour/test/APF0000t6c.jpg
# planetfour/test/APF0000goa.jpg
# planetfour/test/APF0000jny.jpg
# planetfour/test/APF000030w.jpg
# planetfour/test/APF0000d2n.jpg
# planetfour/test/APF0000uca.jpg
# planetfour/test/APF0000ek1.jpg
# planetfour/test/APF00003gr.jpg
# planetfour/test/APF0000rqs.jpg
# planetfour/test/APF0000ksn.jpg
# planetfour/test/APF00001n3.jpg
# planetfour/test/APF00001fv.jpg
# planetfour/test/APF0000r99.jpg
# planetfour/test/APF0000234.jpg
# planetfour/test/APF0000ql3.jpg
# planetfour/test/APF00006nk.jpg
# planetfour/test/APF0000ocb.jpg
# planetfour/test/APF00000yw.jpg
# planetfour/test/APF0000shi.jpg
# planetfour/test/APF00009sk.jpg
# planetfour/test/APF0000rjr.jpg
# planetfour/test/APF0000p9m.jpg
# planetfour/test/APF0000ezn.jpg
# planetfour/test/APF00004mr.jpg
# planetfour/test/APF00003wl.jpg
# planetfour/test/APF000091a.jpg
# planetfour/test/APF0000uwb.jpg
# planetfour/test/APF00009u1.jpg
# planetfour/test/APF0000fw7.jpg
# planetfour/test/APF0000bxf.jpg
# planetfour/test/APF0000eyg.jpg
# planetfour/test/APF0000j98.jpg
# planetfour/test/APF0000vbi.jpg
# planetfour/test/APF0000qec.jpg
# planetfour/test/APF0000hvv.jpg
# planetfour/test/APF0000ov7.jpg
# planetfour/test/APF0000h3t.jpg
# planetfour/test/APF00006zg.jpg
# planetfour/test/APF0000cl2.jpg
# planetfour/test/APF000000j.jpg
# planetfour/test/APF000087g.jpg
# planetfour/test/APF0000apu.jpg
# planetfour/test/APF0000lvh.jpg
# planetfour/test/APF0000kqe.jpg
# planetfour/test/APF0000tj5.jpg
# planetfour/test/APF0000la1.jpg
# planetfour/test/APF00007z7.jpg
# planetfour/test/APF00005s5.jpg
# planetfour/test/APF0000199.jpg
# planetfour/test/APF00002k1.jpg
# planetfour/test/APF0000vdu.jpg
# planetfour/test/APF0000bti.jpg
# planetfour/test/APF00007pb.jpg
# planetfour/test/APF0000vpe.jpg
# planetfour/test/APF00001lq.jpg
# planetfour/test/APF00004uo.jpg
# planetfour/test/APF00006iv.jpg
# planetfour/test/APF0000i6c.jpg
# planetfour/test/APF0000r0t.jpg
# planetfour/test/APF000095k.jpg
# planetfour/test/APF00006ul.jpg
# planetfour/test/APF0000qqs.jpg
# planetfour/test/APF0000ffd.jpg
# planetfour/test/APF0000qn7.jpg
# planetfour/test/APF0000jit.jpg
# planetfour/test/APF00001mo.jpg
# planetfour/test/APF00001lv.jpg
# planetfour/test/APF0000vef.jpg
# planetfour/test/APF0000sua.jpg
# planetfour/test/APF000015j.jpg
# planetfour/test/APF0000rjo.jpg
# planetfour/test/APF0000pdl.jpg
# planetfour/test/APF00003dl.jpg
# planetfour/test/APF0000i49.jpg
# planetfour/test/APF0000ni4.jpg
# planetfour/test/APF0000rkr.jpg
# planetfour/test/APF000006m.jpg
# planetfour/test/APF0000fv2.jpg
# planetfour/test/APF0000pcg.jpg
# planetfour/test/APF0000j5o.jpg
# planetfour/test/APF0000mwh.jpg
# planetfour/test/APF0000wvz.jpg
# planetfour/test/APF00007cu.jpg
# planetfour/test/APF0000bs0.jpg
# planetfour/test/APF0000vlo.jpg
# planetfour/test/APF0000trz.jpg
# planetfour/test/APF00001t5.jpg
# planetfour/test/APF0000fdg.jpg
# planetfour/test/APF0000kib.jpg
# planetfour/test/APF000032h.jpg
# planetfour/test/APF0000dsl.jpg
# planetfour/test/APF0000a0c.jpg
# planetfour/test/APF0000ju5.jpg
# planetfour/test/APF0000bm3.jpg
# planetfour/test/APF00005p6.jpg
# planetfour/test/APF00007eo.jpg
# planetfour/test/APF00008u1.jpg
# planetfour/test/APF0000i59.jpg
# planetfour/test/APF0000h89.jpg
# planetfour/test/APF00002sr.jpg
# planetfour/test/APF0000tou.jpg
# planetfour/test/APF000033i.jpg
# planetfour/test/APF0000ti0.jpg
# planetfour/test/APF0000bs5.jpg
# planetfour/test/APF0000jjs.jpg
# planetfour/test/APF00005ub.jpg
# planetfour/test/APF0000u8c.jpg
# planetfour/test/APF0000uf2.jpg
# planetfour/test/APF0000pk4.jpg
# planetfour/test/APF0000b4l.jpg
# planetfour/test/APF0000sww.jpg
# planetfour/test/APF0000aic.jpg
# planetfour/test/APF0000jlw.jpg
# planetfour/test/APF00001aj.jpg
# planetfour/test/APF0000cfg.jpg
# planetfour/test/APF0000wsu.jpg
# planetfour/test/APF0000lcq.jpg
# planetfour/test/APF0000k75.jpg
# planetfour/test/APF0000jj0.jpg
# planetfour/test/APF0000kvx.jpg
# planetfour/test/APF0000e8j.jpg
# planetfour/test/APF00007jh.jpg
# planetfour/test/APF0000fwi.jpg
# planetfour/test/APF0000jkj.jpg
# planetfour/test/APF0000v7z.jpg
# planetfour/test/APF0000cvv.jpg
# planetfour/test/APF0000bil.jpg
# planetfour/test/APF0000kq0.jpg
# planetfour/test/APF0000whs.jpg
# planetfour/test/APF0000sfk.jpg
# planetfour/test/APF00003tp.jpg
# planetfour/test/APF00003z5.jpg
# planetfour/test/APF00004au.jpg
# planetfour/test/APF0000q1w.jpg
# planetfour/test/APF0000ktq.jpg
# planetfour/test/APF0000ikf.jpg
# planetfour/test/APF0000l1s.jpg
# planetfour/test/APF0000kqc.jpg
# planetfour/test/APF0000ey5.jpg
# planetfour/test/APF0000ngh.jpg
# planetfour/test/APF00006ru.jpg
# planetfour/test/APF00002x2.jpg
# planetfour/test/APF0000480.jpg
# planetfour/test/APF0000j3z.jpg
# planetfour/test/APF00001zh.jpg
# planetfour/test/APF0000b6e.jpg
# planetfour/test/APF0000282.jpg
# planetfour/test/APF0000gj8.jpg
# planetfour/test/APF0000wii.jpg
# planetfour/test/APF0000b51.jpg
# planetfour/test/APF00007d2.jpg
# planetfour/test/APF0000q12.jpg
# planetfour/test/APF0000ai0.jpg
# planetfour/test/APF000025q.jpg
# planetfour/test/APF00000ig.jpg
# planetfour/test/APF0000bnv.jpg
# planetfour/test/APF00002r5.jpg
# planetfour/test/APF0000rxw.jpg
# planetfour/test/APF0000oi1.jpg
# planetfour/test/APF00006im.jpg
# planetfour/test/APF0000wyo.jpg
# planetfour/test/APF000006u.jpg
# planetfour/test/APF00000ey.jpg
# planetfour/test/APF00003hm.jpg
# planetfour/test/APF0000mpu.jpg
# planetfour/test/APF00007l8.jpg
# planetfour/test/APF0000h25.jpg
# planetfour/test/APF0000bx6.jpg
# planetfour/test/APF0000hjy.jpg
# planetfour/test/APF00005rj.jpg
# planetfour/test/APF0000jsi.jpg
# planetfour/test/APF0000uj2.jpg
# planetfour/test/APF0000hwp.jpg
# planetfour/test/APF00002tv.jpg
# planetfour/test/APF0000kzt.jpg
# planetfour/test/APF00006iq.jpg
# planetfour/test/APF00009en.jpg
# planetfour/test/APF0000v4h.jpg
# planetfour/test/APF0000q2q.jpg
# planetfour/test/APF0000jjn.jpg
# planetfour/test/APF00001kj.jpg
# planetfour/test/APF000041i.jpg
# planetfour/test/APF00008pt.jpg
# planetfour/test/APF0000vcz.jpg
# planetfour/test/APF00002qa.jpg
# planetfour/test/APF00009ub.jpg
# planetfour/test/APF00002u6.jpg
# planetfour/test/APF0000v7i.jpg
# planetfour/test/APF0000i5a.jpg
# planetfour/test/APF0000kn3.jpg
# planetfour/test/APF0000ovr.jpg
# planetfour/test/APF0000pdp.jpg
# planetfour/test/APF0000qii.jpg
# planetfour/test/APF0000eji.jpg
# planetfour/test/APF00005g3.jpg
# planetfour/test/APF0000akh.jpg
# planetfour/test/APF0000gmp.jpg
# planetfour/test/APF0000i4d.jpg
# planetfour/test/APF0000po5.jpg
# planetfour/test/APF0000f36.jpg
# planetfour/test/APF0000ufn.jpg
# planetfour/test/APF0000n53.jpg
# planetfour/test/APF0000vst.jpg
# planetfour/test/APF0000uab.jpg
# planetfour/test/APF0000in9.jpg
# planetfour/test/APF000055h.jpg
# planetfour/test/APF0000cjo.jpg
# planetfour/test/APF0000gqm.jpg
# planetfour/test/APF00002sy.jpg
# planetfour/test/APF0000b9s.jpg
# planetfour/test/APF0000sgk.jpg
# planetfour/test/APF00003zv.jpg
# planetfour/test/APF0000th8.jpg
# planetfour/test/APF0000hsc.jpg
# planetfour/test/APF00005ys.jpg
# planetfour/test/APF0000q8g.jpg
# planetfour/test/APF000034p.jpg
# planetfour/test/APF00009ci.jpg
# planetfour/test/APF00000bk.jpg
# planetfour/test/APF0000m0p.jpg
# planetfour/test/APF000020u.jpg
# planetfour/test/APF00007n5.jpg
# planetfour/test/APF0000bbk.jpg
# planetfour/test/APF00001u9.jpg
# planetfour/test/APF00008bl.jpg
# planetfour/test/APF00009cj.jpg
# planetfour/test/APF0000ajl.jpg
# planetfour/test/APF00002cr.jpg
# planetfour/test/APF0000083.jpg
# planetfour/test/APF00005e9.jpg
# planetfour/test/APF00007o9.jpg
# planetfour/test/APF0000w06.jpg
# planetfour/test/APF0000jtr.jpg
# planetfour/test/APF00001mt.jpg
# planetfour/test/APF0000w89.jpg
# planetfour/test/APF0000pdc.jpg
# planetfour/test/APF0000r86.jpg
# planetfour/test/APF00000v4.jpg
# planetfour/test/APF0000dyl.jpg
# planetfour/test/APF0000ivc.jpg
# planetfour/test/APF0000he1.jpg
# planetfour/test/APF0000n2g.jpg
# planetfour/test/APF0000irx.jpg
# planetfour/test/APF0000fai.jpg
# planetfour/test/APF00002w8.jpg
# planetfour/test/APF0000q22.jpg
# planetfour/test/APF00000qc.jpg
# planetfour/test/APF00009pa.jpg
# planetfour/test/APF0000htm.jpg
# planetfour/test/APF00000ix.jpg
# planetfour/test/APF0000n2t.jpg
# planetfour/test/APF0000dj5.jpg
# planetfour/test/APF0000sr5.jpg
# planetfour/test/APF0000q0x.jpg
# planetfour/test/APF0000rk1.jpg
# planetfour/test/APF00006rx.jpg
# planetfour/test/APF0000ex7.jpg
# planetfour/test/APF0000kiq.jpg
# planetfour/test/APF0000q6q.jpg
# planetfour/test/APF000077z.jpg
# planetfour/test/APF0000pei.jpg
# planetfour/test/APF0000asg.jpg
# planetfour/test/APF000034m.jpg
# planetfour/test/APF00001d1.jpg
# planetfour/test/APF0000htt.jpg
# planetfour/test/APF00000cn.jpg
# planetfour/test/APF0000teg.jpg
# planetfour/test/APF0000i6i.jpg
# planetfour/test/APF0000dzo.jpg
# planetfour/test/APF0000ugf.jpg
# planetfour/test/APF0000nh0.jpg
# planetfour/test/APF00001q4.jpg
# planetfour/test/APF0000nj2.jpg
# planetfour/test/APF0000u6c.jpg
# planetfour/test/APF0000da0.jpg
# planetfour/test/APF0000alz.jpg
# planetfour/test/APF0000j9o.jpg
# planetfour/test/APF0000kdy.jpg
# planetfour/test/APF0000mwc.jpg
# planetfour/test/APF0000dwv.jpg
# planetfour/test/APF00000wh.jpg
# planetfour/test/APF0000hwu.jpg
# planetfour/test/APF0000hh6.jpg
# planetfour/test/APF0000any.jpg
# planetfour/test/APF0000ha9.jpg
# planetfour/test/APF0000s0x.jpg
# planetfour/test/APF0000muz.jpg
# planetfour/test/APF0000udr.jpg
# planetfour/test/APF0000hdo.jpg
# planetfour/test/APF00006zv.jpg
# planetfour/test/APF0000v9r.jpg
# planetfour/test/APF0000osb.jpg
# planetfour/test/APF0000en5.jpg
# planetfour/test/APF0000hzx.jpg
# planetfour/test/APF0000ijw.jpg
# planetfour/test/APF0000ct1.jpg
# planetfour/test/APF0000jos.jpg
# planetfour/test/APF0000arr.jpg
# planetfour/test/APF000048k.jpg
# planetfour/test/APF0000tjh.jpg
# planetfour/test/APF000091o.jpg
# planetfour/test/APF00003c2.jpg
# planetfour/test/APF0000pno.jpg
# planetfour/test/APF00003s1.jpg
# planetfour/test/APF00005jp.jpg
# planetfour/test/APF0000cjz.jpg
# planetfour/test/APF0000bzj.jpg
# planetfour/test/APF0000vjf.jpg
# planetfour/test/APF00002lu.jpg
# planetfour/test/APF0000wvr.jpg
# planetfour/test/APF00006d5.jpg
# planetfour/test/APF0000gi0.jpg
# planetfour/test/APF0000esy.jpg
# planetfour/test/APF0000bf1.jpg
# planetfour/test/APF0000qzf.jpg
# planetfour/test/APF0000muj.jpg
# planetfour/test/APF0000rap.jpg
# planetfour/test/APF00006pz.jpg
# planetfour/test/APF0000fbw.jpg
# planetfour/test/APF0000o6m.jpg
# planetfour/test/APF0000319.jpg
# planetfour/test/APF0000wns.jpg
# planetfour/test/APF00009bq.jpg
# planetfour/test/APF0000q7b.jpg
# planetfour/test/APF00000fo.jpg
# planetfour/test/APF000003d.jpg
# planetfour/test/APF00002c3.jpg
# planetfour/test/APF0000ru5.jpg
# planetfour/test/APF00004az.jpg
# planetfour/test/APF00002st.jpg
# planetfour/test/APF00006ro.jpg
# planetfour/test/APF0000aul.jpg
# planetfour/test/APF000030p.jpg
# planetfour/test/APF000078f.jpg
# planetfour/test/APF00001ww.jpg
# planetfour/test/APF0000rju.jpg
# planetfour/test/APF0000myw.jpg
# planetfour/test/APF0000o8f.jpg
# planetfour/test/APF0000de3.jpg
# planetfour/test/APF000062z.jpg
# planetfour/test/APF0000iey.jpg
# planetfour/test/APF0000ifk.jpg
# planetfour/test/APF0000nwd.jpg
# planetfour/test/APF00001yd.jpg
# planetfour/test/APF00000nj.jpg
# planetfour/test/APF0000scl.jpg
# planetfour/test/APF0000kgp.jpg
# planetfour/test/APF0000cb4.jpg
# planetfour/test/APF0000d9w.jpg
# planetfour/test/APF0000q8k.jpg
# planetfour/test/APF0000a47.jpg
# planetfour/test/APF0000q8w.jpg
# planetfour/test/APF0000a00.jpg
# planetfour/test/APF0000k34.jpg
# planetfour/test/APF0000lke.jpg
# planetfour/test/APF00008nz.jpg
# planetfour/test/APF0000vdy.jpg
# planetfour/test/APF0000tck.jpg
# planetfour/test/APF0000kg0.jpg
# planetfour/test/APF000020h.jpg
# planetfour/test/APF0000mjw.jpg
# planetfour/test/APF0000b8y.jpg
# planetfour/test/APF00008y9.jpg
# planetfour/test/APF0000wr1.jpg
# planetfour/test/APF0000kgm.jpg
# planetfour/test/APF0000a7t.jpg
# planetfour/test/APF0000nni.jpg
# planetfour/test/APF0000kc0.jpg
# planetfour/test/APF0000w9c.jpg
# planetfour/test/APF0000ugh.jpg
# planetfour/test/APF0000n18.jpg
# planetfour/test/APF0000bdr.jpg
# planetfour/test/APF0000cuj.jpg
# planetfour/test/APF0000h52.jpg
# planetfour/test/APF0000vdx.jpg
# planetfour/test/APF0000pxh.jpg
# planetfour/test/APF0000nll.jpg
# planetfour/test/APF0000jtc.jpg
# planetfour/test/APF0000kes.jpg
# planetfour/test/APF0000pa3.jpg
# planetfour/test/APF0000cqz.jpg
# planetfour/test/APF00000dx.jpg
# planetfour/test/APF0000qav.jpg
# planetfour/test/APF0000o6p.jpg
# planetfour/test/APF0000bpx.jpg
# planetfour/test/APF00005m2.jpg
# planetfour/test/APF00000dv.jpg
# planetfour/test/APF0000qrj.jpg
# planetfour/test/APF0000q47.jpg
# planetfour/test/APF0000jso.jpg
# planetfour/test/APF000047s.jpg
# planetfour/test/APF0000be1.jpg
# planetfour/test/APF0000niy.jpg
# planetfour/test/APF0000vx7.jpg
# planetfour/test/APF00009ej.jpg
# planetfour/test/APF0000ixc.jpg
# planetfour/test/APF0000ji2.jpg
# planetfour/test/APF0000qck.jpg
# planetfour/test/APF00009qt.jpg
# planetfour/test/APF0000gma.jpg
# planetfour/test/APF0000a2q.jpg
# planetfour/test/APF0000kc8.jpg
# planetfour/test/APF000088p.jpg
# planetfour/test/APF0000b2u.jpg
# planetfour/test/APF0000qyu.jpg
# planetfour/test/APF0000an0.jpg
# planetfour/test/APF0000cna.jpg
# planetfour/test/APF00002zh.jpg
# planetfour/test/APF00009og.jpg
# planetfour/test/APF000031r.jpg
# planetfour/test/APF0000wqj.jpg
# planetfour/test/APF00001n9.jpg
# planetfour/test/APF0000q04.jpg
# planetfour/test/APF0000icu.jpg
# planetfour/test/APF0000jt1.jpg
# planetfour/test/APF00007s8.jpg
# planetfour/test/APF0000d3d.jpg
# planetfour/test/APF00002l7.jpg
# planetfour/test/APF0000dqy.jpg
# planetfour/test/APF0000sjx.jpg
# planetfour/test/APF0000e16.jpg
# planetfour/test/APF00005oy.jpg
# planetfour/test/APF00007kq.jpg
# planetfour/test/APF0000b9t.jpg
# planetfour/test/APF0000fwl.jpg
# planetfour/test/APF0000dzh.jpg
# planetfour/test/APF0000r5w.jpg
# planetfour/test/APF0000st1.jpg
# planetfour/test/APF00006cp.jpg
# planetfour/test/APF0000w8o.jpg
# planetfour/test/APF0000ftd.jpg
# planetfour/test/APF0000epu.jpg
# planetfour/test/APF00006f8.jpg
# planetfour/test/APF0000edd.jpg
# planetfour/test/APF0000vys.jpg
# planetfour/test/APF0000wwf.jpg
# planetfour/test/APF0000gky.jpg
# planetfour/test/APF0000tmy.jpg
# planetfour/test/APF0000kjn.jpg
# planetfour/test/APF0000oih.jpg
# planetfour/test/APF0000r4x.jpg
# planetfour/test/APF00001uc.jpg
# planetfour/test/APF0000s0d.jpg
# planetfour/test/APF0000czt.jpg
# planetfour/test/APF0000typ.jpg
# planetfour/test/APF00008po.jpg
# planetfour/test/APF00001o2.jpg
# planetfour/test/APF0000mxv.jpg
# planetfour/test/APF00007gg.jpg
# planetfour/test/APF0000hr6.jpg
# planetfour/test/APF00002s5.jpg
# planetfour/test/APF0000i7g.jpg
# planetfour/test/APF00008lk.jpg
# planetfour/test/APF0000m4h.jpg
# planetfour/test/APF00005wh.jpg
# planetfour/test/APF0000bm6.jpg
# planetfour/test/APF0000tgd.jpg
# planetfour/test/APF00002pf.jpg
# planetfour/test/APF0000hd4.jpg
# planetfour/test/APF0000bfl.jpg
# planetfour/test/APF0000ii7.jpg
# planetfour/test/APF0000tey.jpg
# planetfour/test/APF000086m.jpg
# planetfour/test/APF0000gh5.jpg
# planetfour/test/APF0000tjc.jpg
# planetfour/test/APF00005du.jpg
# planetfour/test/APF0000ppg.jpg
# planetfour/test/APF0000br2.jpg
# planetfour/test/APF0000px9.jpg
# planetfour/test/APF00001tz.jpg
# planetfour/test/APF0000op8.jpg
# planetfour/test/APF000076h.jpg
# planetfour/test/APF0000tri.jpg
# planetfour/test/APF0000huf.jpg
# planetfour/test/APF00007f5.jpg
# planetfour/test/APF0000ocs.jpg
# planetfour/test/APF0000v78.jpg
# planetfour/test/APF0000f7l.jpg
# planetfour/test/APF0000wj8.jpg
# planetfour/test/APF0000ew2.jpg
# planetfour/test/APF00006wm.jpg
# planetfour/test/APF00003st.jpg
# planetfour/test/APF0000tqi.jpg
# planetfour/test/APF0000rtn.jpg
# planetfour/test/APF0000w1h.jpg
# planetfour/test/APF0000u8e.jpg
# planetfour/test/APF0000vbk.jpg
# planetfour/test/APF000086t.jpg
# planetfour/test/APF0000jj2.jpg
# planetfour/test/APF0000q9e.jpg
# planetfour/test/APF0000awz.jpg
# planetfour/test/APF0000hns.jpg
# planetfour/test/APF0000iay.jpg
# planetfour/test/APF0000nma.jpg
# planetfour/test/APF0000wg0.jpg
# planetfour/test/APF0000wa8.jpg
# planetfour/test/APF0000emj.jpg
# planetfour/test/APF0000ch2.jpg
# planetfour/test/APF0000wds.jpg
# planetfour/test/APF00003vg.jpg
# planetfour/test/APF0000ekx.jpg
# planetfour/test/APF00007nt.jpg
# planetfour/test/APF0000f94.jpg
# planetfour/test/APF0000lbm.jpg
# planetfour/test/APF0000acp.jpg
# planetfour/test/APF0000gyf.jpg
# planetfour/test/APF0000g5f.jpg
# planetfour/test/APF00007cq.jpg
# planetfour/test/APF0000ec0.jpg
# planetfour/test/APF0000b15.jpg
# planetfour/test/APF00000cl.jpg
# planetfour/test/APF0000kfw.jpg
# planetfour/test/APF00002qc.jpg
# planetfour/test/APF0000oqy.jpg
# planetfour/test/APF0000t8j.jpg
# planetfour/test/APF00007sw.jpg
# planetfour/test/APF0000hc6.jpg
# planetfour/test/APF0000kzq.jpg
# planetfour/test/APF000065x.jpg
# planetfour/test/APF0000nho.jpg
# planetfour/test/APF0000nzt.jpg
# planetfour/test/APF0000kl2.jpg
# planetfour/test/APF0000hel.jpg
# planetfour/test/APF0000nl8.jpg
# planetfour/test/APF000032d.jpg
# planetfour/test/APF00008o7.jpg
# planetfour/test/APF0000m41.jpg
# planetfour/test/APF0000bd4.jpg
# planetfour/test/APF0000vbv.jpg
# planetfour/test/APF0000ou7.jpg
# planetfour/test/APF0000nr0.jpg
# planetfour/test/APF0000i1s.jpg
# planetfour/test/APF0000bck.jpg
# planetfour/test/APF00009ln.jpg
# planetfour/test/APF00002es.jpg
# planetfour/test/APF000011c.jpg
# planetfour/test/APF000066f.jpg
# planetfour/test/APF0000lih.jpg
# planetfour/test/APF0000h9f.jpg
# planetfour/test/APF0000v8e.jpg
# planetfour/test/APF00005mn.jpg
# planetfour/test/APF0000wmb.jpg
# planetfour/test/APF0000a8p.jpg
# planetfour/test/APF0000fc0.jpg
# planetfour/test/APF00006e7.jpg
# planetfour/test/APF0000tc4.jpg
# planetfour/test/APF00005vs.jpg
# planetfour/test/APF00007tn.jpg
# planetfour/test/APF0000jda.jpg
# planetfour/test/APF0000mpy.jpg
# planetfour/test/APF000080f.jpg
# planetfour/test/APF0000dd7.jpg
# planetfour/test/APF0000seu.jpg
# planetfour/test/APF0000bko.jpg
# planetfour/test/APF0000w46.jpg
# planetfour/test/APF00000wz.jpg
# planetfour/test/APF000094a.jpg
# planetfour/test/APF0000b82.jpg
# planetfour/test/APF000061b.jpg
# planetfour/test/APF00005lh.jpg
# planetfour/test/APF0000b7k.jpg
# planetfour/test/APF00004t0.jpg
# planetfour/test/APF0000gv9.jpg
# planetfour/test/APF0000grb.jpg
# planetfour/test/APF0000p60.jpg
# planetfour/test/APF0000pw8.jpg
# planetfour/test/APF00002h1.jpg
# planetfour/test/APF00003qu.jpg
# planetfour/test/APF00000eu.jpg
# planetfour/test/APF0000h79.jpg
# planetfour/test/APF0000365.jpg
# planetfour/test/APF0000gn2.jpg
# planetfour/test/APF0000ijc.jpg
# planetfour/test/APF0000gu8.jpg
# planetfour/test/APF0000fx3.jpg
# planetfour/test/APF00009uq.jpg
# planetfour/test/APF00007gu.jpg
# planetfour/test/APF00006f7.jpg
# planetfour/test/APF0000r65.jpg
# planetfour/test/APF0000jf9.jpg
# planetfour/test/APF00006nr.jpg
# planetfour/test/APF0000k5y.jpg
# planetfour/test/APF0000kkn.jpg
# planetfour/test/APF0000832.jpg
# planetfour/test/APF0000c0m.jpg
# planetfour/test/APF00007my.jpg
# planetfour/test/APF0000vdr.jpg
# planetfour/test/APF000015x.jpg
# planetfour/test/APF0000kah.jpg
# planetfour/test/APF0000qot.jpg
# planetfour/test/APF000001d.jpg
# planetfour/test/APF00000es.jpg
# planetfour/test/APF00001tv.jpg
# planetfour/test/APF0000mvq.jpg
# planetfour/test/APF0000wc4.jpg
# planetfour/test/APF0000c1t.jpg
# planetfour/test/APF0000vvn.jpg
# planetfour/test/APF0000wsf.jpg
# planetfour/test/APF0000wls.jpg
# planetfour/test/APF00002ay.jpg
# planetfour/test/APF0000ia9.jpg
# planetfour/test/APF0000pzr.jpg
# planetfour/test/APF0000wrn.jpg
# planetfour/test/APF0000387.jpg
# planetfour/test/APF0000tae.jpg
# planetfour/test/APF0000fx7.jpg
# planetfour/test/APF0000kj5.jpg
# planetfour/test/APF00006yn.jpg
# planetfour/test/APF0000wth.jpg
# planetfour/test/APF00001hr.jpg
# planetfour/test/APF0000pgz.jpg
# planetfour/test/APF0000px1.jpg
# planetfour/test/APF0000v3w.jpg
# planetfour/test/APF00008jy.jpg
# planetfour/test/APF0000qd8.jpg
# planetfour/test/APF0000k4w.jpg
# planetfour/test/APF0000i8e.jpg
# planetfour/test/APF0000cfi.jpg
# planetfour/test/APF0000udn.jpg
# planetfour/test/APF0000agz.jpg
# planetfour/test/APF0000si4.jpg
# planetfour/test/APF0000pgo.jpg
# planetfour/test/APF0000q05.jpg
# planetfour/test/APF0000uc9.jpg
# planetfour/test/APF00005tf.jpg
# planetfour/test/APF0000nvm.jpg
# planetfour/test/APF0000fuh.jpg
# planetfour/test/APF0000ml5.jpg
# planetfour/test/APF000014t.jpg
# planetfour/test/APF0000hv7.jpg
# planetfour/test/APF00009jz.jpg
# planetfour/test/APF00005gt.jpg
# planetfour/test/APF00005vn.jpg
# planetfour/test/APF0000sph.jpg
# planetfour/test/APF00002q3.jpg
# planetfour/test/APF0000sz7.jpg
# planetfour/test/APF0000eyi.jpg
# planetfour/test/APF0000mod.jpg
# planetfour/test/APF0000d7n.jpg
# planetfour/test/APF0000qb2.jpg
# planetfour/test/APF0000n12.jpg
# planetfour/test/APF0000rza.jpg
# planetfour/test/APF0000t5h.jpg
# planetfour/test/APF0000dof.jpg
# planetfour/test/APF0000tkw.jpg
# planetfour/test/APF0000quz.jpg
# planetfour/test/APF0000b6t.jpg
# planetfour/test/APF0000ntm.jpg
# planetfour/test/APF00000a9.jpg
# planetfour/test/APF0000kod.jpg
# planetfour/test/APF0000wtn.jpg
# planetfour/test/APF0000mbq.jpg
# planetfour/test/APF0000g42.jpg
# planetfour/test/APF0000qto.jpg
# planetfour/test/APF0000in0.jpg
# planetfour/test/APF0000hx3.jpg
# planetfour/test/APF0000hpt.jpg
# planetfour/test/APF0000s7f.jpg
# planetfour/test/APF0000n1b.jpg
# planetfour/test/APF0000a1j.jpg
# planetfour/test/APF0000tk0.jpg
# planetfour/test/APF0000tnw.jpg
# planetfour/test/APF0000a1l.jpg
# planetfour/test/APF0000pxi.jpg
# planetfour/test/APF0000ngz.jpg
# planetfour/test/APF0000krw.jpg
# planetfour/test/APF0000krs.jpg
# planetfour/test/APF0000k99.jpg
# planetfour/test/APF0000byu.jpg
# planetfour/test/APF00009b3.jpg
# planetfour/test/APF0000u3y.jpg
# planetfour/test/APF0000ms9.jpg
# planetfour/test/APF00008fj.jpg
# planetfour/test/APF0000qbh.jpg
# planetfour/test/APF0000tos.jpg
# planetfour/test/APF0000ekp.jpg
# planetfour/test/APF0000j15.jpg
# planetfour/test/APF00006hg.jpg
# planetfour/test/APF0000l3y.jpg
# planetfour/test/APF00000hn.jpg
# planetfour/test/APF0000r9l.jpg
# planetfour/test/APF00003ah.jpg
# planetfour/test/APF00009mf.jpg
# planetfour/test/APF0000qw0.jpg
# planetfour/test/APF00002ot.jpg
# planetfour/test/APF00004da.jpg
# planetfour/test/APF0000qs0.jpg
# planetfour/test/APF0000j9w.jpg
# planetfour/test/APF0000w45.jpg
# planetfour/test/APF0000v8p.jpg
# planetfour/test/APF0000q4w.jpg
# planetfour/test/APF00006le.jpg
# planetfour/test/APF000090i.jpg
# planetfour/test/APF0000evq.jpg
# planetfour/test/APF0000si8.jpg
# planetfour/test/APF000092x.jpg
# planetfour/test/APF0000w8e.jpg
# planetfour/test/APF0000eju.jpg
# planetfour/test/APF00006ej.jpg
# planetfour/test/APF00009vj.jpg
# planetfour/test/APF0000p69.jpg
# planetfour/test/APF0000mz6.jpg
# planetfour/test/APF0000ijj.jpg
# planetfour/test/APF0000w1v.jpg
# planetfour/test/APF0000baw.jpg
# planetfour/test/APF0000ah3.jpg
# planetfour/test/APF0000fr3.jpg
# planetfour/test/APF0000iqi.jpg
# planetfour/test/APF0000i2a.jpg
# planetfour/test/APF00006y8.jpg
# planetfour/test/APF0000gld.jpg
# planetfour/test/APF00007jq.jpg
# planetfour/test/APF0000pho.jpg
# planetfour/test/APF0000ogt.jpg
# planetfour/test/APF0000wy3.jpg
# planetfour/test/APF0000pf2.jpg
# planetfour/test/APF0000n7s.jpg
# planetfour/test/APF0000x1g.jpg
# planetfour/test/APF0000n1j.jpg
# planetfour/test/APF0000qij.jpg
# planetfour/test/APF0000rz2.jpg
# planetfour/test/APF0000d1b.jpg
# planetfour/test/APF0000020.jpg
# planetfour/test/APF0000kt5.jpg
# planetfour/test/APF0000s2s.jpg
# planetfour/test/APF0000mpp.jpg
# planetfour/test/APF0000s9s.jpg
# planetfour/test/APF00004b4.jpg
# planetfour/test/APF0000r50.jpg
# planetfour/test/APF00007iu.jpg
# planetfour/test/APF0000ck2.jpg
# planetfour/test/APF00005sa.jpg
# planetfour/test/APF00001da.jpg
# planetfour/test/APF0000gdi.jpg
# planetfour/test/APF00004ce.jpg
# planetfour/test/APF0000d6m.jpg
# planetfour/test/APF0000biu.jpg
# planetfour/test/APF00003dj.jpg
# planetfour/test/APF0000csn.jpg
# planetfour/test/APF0000iqx.jpg
# planetfour/test/APF0000bmb.jpg
# planetfour/test/APF0000euu.jpg
# planetfour/test/APF0000bgf.jpg
# planetfour/test/APF0000kg3.jpg
# planetfour/test/APF0000w9o.jpg
# planetfour/test/APF0000n7w.jpg
# planetfour/test/APF0000o0m.jpg
# planetfour/test/APF00000u6.jpg
# planetfour/test/APF0000476.jpg
# planetfour/test/APF0000vyo.jpg
# planetfour/test/APF00000vk.jpg
# planetfour/test/APF000030q.jpg
# planetfour/test/APF00004ea.jpg
# planetfour/test/APF000081b.jpg
# planetfour/test/APF0000jdz.jpg
# planetfour/test/APF0000r7f.jpg
# planetfour/test/APF00005h4.jpg
# planetfour/test/APF00002ne.jpg
# planetfour/test/APF00007z0.jpg
# planetfour/test/APF0000s22.jpg
# planetfour/test/APF0000q0i.jpg
# planetfour/test/APF0000gpi.jpg
# planetfour/test/APF0000mn4.jpg
# planetfour/test/APF0000kzp.jpg
# planetfour/test/APF00001ub.jpg
# planetfour/test/APF0000qdf.jpg
# planetfour/test/APF0000wgv.jpg
# planetfour/test/APF00000h2.jpg
# planetfour/test/APF0000991.jpg
# planetfour/test/APF0000hqc.jpg
# planetfour/test/APF00006w8.jpg
# planetfour/test/APF000072e.jpg
# planetfour/test/APF0000a3e.jpg
# planetfour/test/APF0000a4x.jpg
# planetfour/test/APF0000kz8.jpg
# planetfour/test/APF000024l.jpg
# planetfour/test/APF000021a.jpg
# planetfour/test/APF00006vk.jpg
# planetfour/test/APF0000uqk.jpg
# planetfour/test/APF0000rum.jpg
# planetfour/test/APF0000wtd.jpg
# planetfour/test/APF0000nb0.jpg
# planetfour/test/APF0000p89.jpg
# planetfour/test/APF000044u.jpg
# planetfour/test/APF0000rjk.jpg
# planetfour/test/APF00004bb.jpg
# planetfour/test/APF0000r3a.jpg
# planetfour/test/APF0000rpq.jpg
# planetfour/test/APF0000dxc.jpg
# planetfour/test/APF00006pp.jpg
# planetfour/test/APF0000rib.jpg
# planetfour/test/APF0000sf8.jpg
# planetfour/test/APF000033r.jpg
# planetfour/test/APF0000wrm.jpg
# planetfour/test/APF0000wce.jpg
# planetfour/test/APF0000tmr.jpg
# planetfour/test/APF0000iqs.jpg
# planetfour/test/APF0000qrd.jpg
# planetfour/test/APF0000468.jpg
# planetfour/test/APF0000smg.jpg
# planetfour/test/APF00005xb.jpg
# planetfour/test/APF0000h63.jpg
# planetfour/test/APF00001dh.jpg
# planetfour/test/APF0000n7c.jpg
# planetfour/test/APF0000sq3.jpg
# planetfour/test/APF0000qo7.jpg
# planetfour/test/APF00002ev.jpg
# planetfour/test/APF0000ven.jpg
# planetfour/test/APF00007n8.jpg
# planetfour/test/APF00008mf.jpg
# planetfour/test/APF0000mmi.jpg
# planetfour/test/APF0000kad.jpg
# planetfour/test/APF0000aaj.jpg
# planetfour/test/APF0000how.jpg
# planetfour/test/APF00006k0.jpg
# planetfour/test/APF0000btb.jpg
# planetfour/test/APF0000bk9.jpg
# planetfour/test/APF000023v.jpg
# planetfour/test/APF0000902.jpg
# planetfour/test/APF0000skq.jpg
# planetfour/test/APF00006y3.jpg
# planetfour/test/APF0000blj.jpg
# planetfour/test/APF0000egx.jpg
# planetfour/test/APF0000b56.jpg
# planetfour/test/APF0000s0a.jpg
# planetfour/test/APF0000vkt.jpg
# planetfour/test/APF000035o.jpg
# planetfour/test/APF0000q9l.jpg
# planetfour/test/APF0000t1e.jpg
# planetfour/test/APF00009nt.jpg
# planetfour/test/APF0000fwt.jpg
# planetfour/test/APF0000nnf.jpg
# planetfour/test/APF0000icf.jpg
# planetfour/test/APF0000vew.jpg
# planetfour/test/APF0000t80.jpg
# planetfour/test/APF0000bt3.jpg
# planetfour/test/APF0000bpa.jpg
# planetfour/test/APF00007xg.jpg
# planetfour/test/APF0000am4.jpg
# planetfour/test/APF0000ubs.jpg
# planetfour/test/APF0000qa4.jpg
# planetfour/test/APF0000b0r.jpg
# planetfour/test/APF0000gx9.jpg
# planetfour/test/APF00008qt.jpg
# planetfour/test/APF000048t.jpg
# planetfour/test/APF00001kr.jpg
# planetfour/test/APF000046l.jpg
# planetfour/test/APF00006mg.jpg
# planetfour/test/APF0000btf.jpg
# planetfour/test/APF0000hwq.jpg
# planetfour/test/APF0000ro4.jpg
# planetfour/test/APF0000vwj.jpg
# planetfour/test/APF0000iyv.jpg
# planetfour/test/APF0000hrf.jpg
# planetfour/test/APF0000j0a.jpg
# planetfour/test/APF00006dr.jpg
# planetfour/test/APF0000x32.jpg
# planetfour/test/APF0000meh.jpg
# planetfour/test/APF0000vay.jpg
# planetfour/test/APF0000g2k.jpg
# planetfour/test/APF0000767.jpg
# planetfour/test/APF0000rmg.jpg
# planetfour/test/APF0000pq0.jpg
# planetfour/test/APF00001dq.jpg
# planetfour/test/APF0000gnc.jpg
# planetfour/test/APF0000nqw.jpg
# planetfour/test/APF0000khx.jpg
# planetfour/test/APF00001ez.jpg
# planetfour/test/APF0000ekn.jpg
# planetfour/test/APF0000a0z.jpg
# planetfour/test/APF00006ik.jpg
# planetfour/test/APF0000nr1.jpg
# planetfour/test/APF0000v2j.jpg
# planetfour/test/APF0000bok.jpg
# planetfour/test/APF0000cc4.jpg
# planetfour/test/APF0000cut.jpg
# planetfour/test/APF0000emq.jpg
# planetfour/test/APF0000rka.jpg
# planetfour/test/APF00008vx.jpg
# planetfour/test/APF0000h60.jpg
# planetfour/test/APF0000gw8.jpg
# planetfour/test/APF0000fvb.jpg
# planetfour/test/APF0000e1h.jpg
# planetfour/test/APF0000ail.jpg
# planetfour/test/APF0000wpr.jpg
# planetfour/test/APF0000gi7.jpg
# planetfour/test/APF0000qsk.jpg
# planetfour/test/APF00005kw.jpg
# planetfour/test/APF0000km8.jpg
# planetfour/test/APF000005s.jpg
# planetfour/test/APF0000n8e.jpg
# planetfour/test/APF0000htv.jpg
# planetfour/test/APF0000tbg.jpg
# planetfour/test/APF0000438.jpg
# planetfour/test/APF0000jtf.jpg
# planetfour/test/APF00003n4.jpg
# planetfour/test/APF0000tam.jpg
# planetfour/test/APF0000ax3.jpg
# planetfour/test/APF0000v8y.jpg
# planetfour/test/APF00006of.jpg
# planetfour/test/APF0000cjm.jpg
# planetfour/test/APF0000e88.jpg
# planetfour/test/APF0000i3n.jpg
# planetfour/test/APF00002o4.jpg
# planetfour/test/APF000083z.jpg
# planetfour/test/APF0000wto.jpg
# planetfour/test/APF00006kk.jpg
# planetfour/test/APF00004eq.jpg
# planetfour/test/APF0000iqv.jpg
# planetfour/test/APF0000lck.jpg
# planetfour/test/APF0000wks.jpg
# planetfour/test/APF00005ro.jpg
# planetfour/test/APF0000tn6.jpg
# planetfour/test/APF0000ot1.jpg
# planetfour/test/APF0000ikb.jpg
# planetfour/test/APF0000wln.jpg
# planetfour/test/APF0000s7b.jpg
# planetfour/test/APF00001qa.jpg
# planetfour/test/APF00007hj.jpg
# planetfour/test/APF00002ut.jpg
# planetfour/test/APF00001iy.jpg
# planetfour/test/APF0000i6r.jpg
# planetfour/test/APF0000bh8.jpg
# planetfour/test/APF0000p2b.jpg
# planetfour/test/APF00006xw.jpg
# planetfour/test/APF0000jwf.jpg
# planetfour/test/APF0000bw6.jpg
# planetfour/test/APF000041h.jpg
# planetfour/test/APF0000ffb.jpg
# planetfour/test/APF00005pd.jpg
# planetfour/test/APF00007d3.jpg
# planetfour/test/APF0000j2u.jpg
# planetfour/test/APF0000h32.jpg
# planetfour/test/APF0000sf6.jpg
# planetfour/test/APF0000wk9.jpg
# planetfour/test/APF000019t.jpg
# planetfour/test/APF0000j09.jpg
# planetfour/test/APF0000qzt.jpg
# planetfour/test/APF0000l0j.jpg
# planetfour/test/APF00000sf.jpg
# planetfour/test/APF0000k0g.jpg
# planetfour/test/APF0000qan.jpg
# planetfour/test/APF0000mk0.jpg
# planetfour/test/APF0000k70.jpg
# planetfour/test/APF0000k1u.jpg
# planetfour/test/APF0000tcn.jpg
# planetfour/test/APF0000c99.jpg
# planetfour/test/APF00004ej.jpg
# planetfour/test/APF0000n6y.jpg
# planetfour/test/APF0000dx8.jpg
# planetfour/test/APF0000o8z.jpg
# planetfour/test/APF0000w9r.jpg
# planetfour/test/APF0000kqz.jpg
# planetfour/test/APF0000w8c.jpg
# planetfour/test/APF0000i7l.jpg
# planetfour/test/APF0000rms.jpg
# planetfour/test/APF0000t26.jpg
# planetfour/test/APF00006mx.jpg
# planetfour/test/APF0000jtx.jpg
# planetfour/test/APF00000jv.jpg
# planetfour/test/APF0000cp4.jpg
# planetfour/test/APF0000c9t.jpg
# planetfour/test/APF0000vb2.jpg
# planetfour/test/APF0000beb.jpg
# planetfour/test/APF0000x1o.jpg
# planetfour/test/APF0000r4f.jpg
# planetfour/test/APF0000h8d.jpg
# planetfour/test/APF0000187.jpg
# planetfour/test/APF00006me.jpg
# planetfour/test/APF00007sy.jpg
# planetfour/test/APF0000so0.jpg
# planetfour/test/APF0000atw.jpg
# planetfour/test/APF0000u7o.jpg
# planetfour/test/APF0000f1d.jpg
# planetfour/test/APF0000umm.jpg
# planetfour/test/APF0000tev.jpg
# planetfour/test/APF0000ief.jpg
# planetfour/test/APF0000bft.jpg
# planetfour/test/APF0000uj6.jpg
# planetfour/test/APF0000b0e.jpg
# planetfour/test/APF0000n7g.jpg
# planetfour/test/APF0000ue8.jpg
# planetfour/test/APF0000wzh.jpg
# planetfour/test/APF0000wk4.jpg
# planetfour/test/APF00006k7.jpg
# planetfour/test/APF0000bn5.jpg
# planetfour/test/APF0000i8j.jpg
# planetfour/test/APF00009qj.jpg
# planetfour/test/APF0000j7z.jpg
# planetfour/test/APF00009xr.jpg
# planetfour/test/APF00000tq.jpg
# planetfour/test/APF00009oa.jpg
# planetfour/test/APF00003qe.jpg
# planetfour/test/APF00000zq.jpg
# planetfour/test/APF0000w3z.jpg
# planetfour/test/APF000048n.jpg
# planetfour/test/APF0000sr7.jpg
# planetfour/test/APF00003o5.jpg
# planetfour/test/APF00009cb.jpg
# planetfour/test/APF0000sc6.jpg
# planetfour/test/APF0000s3i.jpg
# planetfour/test/APF0000qkl.jpg
# planetfour/test/APF0000mn1.jpg
# planetfour/test/APF0000ng7.jpg
# planetfour/test/APF0000cqf.jpg
# planetfour/test/APF000085c.jpg
# planetfour/test/APF00009dz.jpg
# planetfour/test/APF0000bkl.jpg
# planetfour/test/APF0000t96.jpg
# planetfour/test/APF0000kfq.jpg
# planetfour/test/APF0000axt.jpg
# planetfour/test/APF0000kqk.jpg
# planetfour/test/APF0000tbu.jpg
# planetfour/test/APF0000m05.jpg
# planetfour/test/APF0000smj.jpg
# planetfour/test/APF0000spy.jpg
# planetfour/test/APF0000x00.jpg
# planetfour/test/APF0000rxm.jpg
# planetfour/test/APF0000ju9.jpg
# planetfour/test/APF00005ms.jpg
# planetfour/test/APF0000k9a.jpg
# planetfour/test/APF0000qe6.jpg
# planetfour/test/APF0000btq.jpg
# planetfour/test/APF0000jf5.jpg
# planetfour/test/APF00002kf.jpg
# planetfour/test/APF0000wq9.jpg
# planetfour/test/APF00007pa.jpg
# planetfour/test/APF00006fz.jpg
# planetfour/test/APF0000sml.jpg
# planetfour/test/APF0000ftm.jpg
# planetfour/test/APF0000u4u.jpg
# planetfour/test/APF00008rg.jpg
# planetfour/test/APF0000mku.jpg
# planetfour/test/APF0000wur.jpg
# planetfour/test/APF0000qdg.jpg
# planetfour/test/APF0000s06.jpg
# planetfour/test/APF0000l5g.jpg
# planetfour/test/APF0000anq.jpg
# planetfour/test/APF0000g1h.jpg
# planetfour/test/APF0000rof.jpg
# planetfour/test/APF00006pv.jpg
# planetfour/test/APF0000rzb.jpg
# planetfour/test/APF00009j1.jpg
# planetfour/test/APF00009oc.jpg
# planetfour/test/APF0000svq.jpg
# planetfour/test/APF0000dzb.jpg
# planetfour/test/APF0000gps.jpg
# planetfour/test/APF0000bu0.jpg
# planetfour/test/APF0000wt2.jpg
# planetfour/test/APF0000n6x.jpg
# planetfour/test/APF0000ox7.jpg
# planetfour/test/APF0000ts3.jpg
# planetfour/test/APF00009zc.jpg
# planetfour/test/APF00009q6.jpg
# planetfour/test/APF0000w03.jpg
# planetfour/test/APF0000tat.jpg
# planetfour/test/APF0000ign.jpg
# planetfour/test/APF0000035.jpg
# planetfour/test/APF0000i0y.jpg
# planetfour/test/APF0000jvz.jpg
# planetfour/test/APF0000kx5.jpg
# planetfour/test/APF000090y.jpg
# planetfour/test/APF00003z0.jpg
# planetfour/test/APF0000kwo.jpg
# planetfour/test/APF0000ov8.jpg
# planetfour/test/APF00009je.jpg
# planetfour/test/APF0000qzn.jpg
# planetfour/test/APF0000bhg.jpg
# planetfour/test/APF0000w7i.jpg
# planetfour/test/APF0000hz0.jpg
# planetfour/test/APF00006zo.jpg
# planetfour/test/APF0000g30.jpg
# planetfour/test/APF00002f0.jpg
# planetfour/test/APF000062e.jpg
# planetfour/test/APF000086h.jpg
# planetfour/test/APF00004c8.jpg
# planetfour/test/APF0000lew.jpg
# planetfour/test/APF000005j.jpg
# planetfour/test/APF0000033.jpg
# planetfour/test/APF0000wg3.jpg
# planetfour/test/APF0000kbk.jpg
# planetfour/test/APF0000kjd.jpg
# planetfour/test/APF0000r74.jpg
# planetfour/test/APF000050h.jpg
# planetfour/test/APF0000u1u.jpg
# planetfour/test/APF0000h7q.jpg
# planetfour/test/APF00003y6.jpg
# planetfour/test/APF0000gn9.jpg
# planetfour/test/APF0000ucd.jpg
# planetfour/test/APF00001r6.jpg
# planetfour/test/APF000078p.jpg
# planetfour/test/APF0000bwf.jpg
# planetfour/test/APF0000wba.jpg
# planetfour/test/APF0000trk.jpg
# planetfour/test/APF0000h8l.jpg
# planetfour/test/APF00000c7.jpg
# planetfour/test/APF0000q2v.jpg
# planetfour/test/APF0000wrc.jpg
# planetfour/test/APF00007b6.jpg
# planetfour/test/APF0000mgs.jpg
# planetfour/test/APF0000m2s.jpg
# planetfour/test/APF0000jjo.jpg
# planetfour/test/APF0000213.jpg
# ...
# planetfour/valid/APF0000fsu.jpg
# planetfour/valid/APF0000cd5.jpg
# planetfour/valid/APF00005wl.jpg
# planetfour/valid/APF0000p1m.jpg
# planetfour/valid/APF0000hzj.jpg
# planetfour/valid/APF0000nlz.jpg
# planetfour/valid/APF00006wg.jpg
# planetfour/valid/APF0000dzx.jpg
# planetfour/valid/APF0000p3l.jpg
# planetfour/valid/APF00000br.jpg
# planetfour/valid/APF00006km.jpg
# planetfour/valid/APF0000byr.jpg
# planetfour/valid/APF0000f1m.jpg
# planetfour/valid/APF0000ha5.jpg
# planetfour/valid/APF00006g8.jpg
# planetfour/valid/APF0000mu4.jpg
# planetfour/valid/APF00008xr.jpg
# planetfour/valid/APF0000mi7.jpg
# planetfour/valid/APF0000d2j.jpg
# planetfour/valid/APF0000anl.jpg
# planetfour/valid/APF0000p86.jpg
# planetfour/valid/APF00007v9.jpg
# planetfour/valid/APF0000hyd.jpg
# planetfour/valid/APF0000cwt.jpg
# planetfour/valid/APF0000vzh.jpg
# planetfour/valid/APF0000lec.jpg
# planetfour/valid/APF0000d5a.jpg
# planetfour/valid/APF0000l0z.jpg
# planetfour/valid/APF000099c.jpg
# planetfour/valid/APF000098t.jpg
# planetfour/valid/APF00001yp.jpg
# planetfour/valid/APF00009j6.jpg
# planetfour/valid/APF0000ohj.jpg
# planetfour/valid/APF0000pr9.jpg
# planetfour/valid/APF00000t8.jpg
# planetfour/valid/APF0000jgj.jpg
# planetfour/valid/APF0000iiy.jpg
# planetfour/valid/APF0000sls.jpg
# planetfour/valid/APF00009bu.jpg
# planetfour/valid/APF0000hx9.jpg
# planetfour/valid/APF0000i6q.jpg
# planetfour/valid/APF0000n40.jpg
# planetfour/valid/APF0000kpb.jpg
# planetfour/valid/APF000063u.jpg
# planetfour/valid/APF0000q02.jpg
# planetfour/valid/APF0000ti4.jpg
# planetfour/valid/APF0000ixh.jpg
# planetfour/valid/APF0000p7j.jpg
# planetfour/valid/APF000062a.jpg
# planetfour/valid/APF0000l0p.jpg
# planetfour/valid/APF0000s0q.jpg
# planetfour/valid/APF0000ov1.jpg
# planetfour/valid/APF0000gp8.jpg
# planetfour/valid/APF0000vyu.jpg
# planetfour/valid/APF00005li.jpg
# planetfour/valid/APF0000hy0.jpg
# planetfour/valid/APF00001rd.jpg
# planetfour/valid/APF0000bb6.jpg
# planetfour/valid/APF0000h9y.jpg
# planetfour/valid/APF0000i16.jpg
# planetfour/valid/APF0000u6b.jpg
# planetfour/valid/APF0000tkn.jpg
# planetfour/valid/APF0000jis.jpg
# planetfour/valid/APF00000he.jpg
# planetfour/valid/APF0000dp9.jpg
# planetfour/valid/APF0000i2j.jpg
# planetfour/valid/APF00003ii.jpg
# planetfour/valid/APF00008pm.jpg
# planetfour/valid/APF00003tu.jpg
# planetfour/valid/APF000088i.jpg
# planetfour/valid/APF00000f0.jpg
# planetfour/valid/APF0000w6a.jpg
# planetfour/valid/APF0000fe6.jpg
# planetfour/valid/APF00003kj.jpg
# planetfour/valid/APF0000359.jpg
# planetfour/valid/APF0000i4a.jpg
# planetfour/valid/APF00000cs.jpg
# planetfour/valid/APF0000k6w.jpg
# planetfour/valid/APF00007ke.jpg
# planetfour/valid/APF0000nxd.jpg
# planetfour/valid/APF0000pad.jpg
# planetfour/valid/APF00003u0.jpg
# planetfour/valid/APF00005lx.jpg
# planetfour/valid/APF00001n0.jpg
# planetfour/valid/APF0000bnl.jpg
# planetfour/valid/APF000006f.jpg
# planetfour/valid/APF00009a1.jpg
# planetfour/valid/APF0000cqy.jpg
# planetfour/valid/APF0000km5.jpg
# planetfour/valid/APF0000uq1.jpg
# planetfour/valid/APF00009fc.jpg
# planetfour/valid/APF0000sa2.jpg
# planetfour/valid/APF0000mp9.jpg
# planetfour/valid/APF0000vdd.jpg
# planetfour/valid/APF0000clz.jpg
# planetfour/valid/APF000024v.jpg
# planetfour/valid/APF00008u0.jpg
# planetfour/valid/APF000047e.jpg
# planetfour/valid/APF0000r0p.jpg
# planetfour/valid/APF0000si3.jpg
# planetfour/valid/APF00005sr.jpg
# planetfour/valid/APF0000jhp.jpg
# planetfour/valid/APF0000m4x.jpg
# planetfour/valid/APF00009xg.jpg
# planetfour/valid/APF0000plx.jpg
# planetfour/valid/APF0000cem.jpg
# planetfour/valid/APF0000kbi.jpg
# planetfour/valid/APF0000w8l.jpg
# planetfour/valid/APF00000jg.jpg
# planetfour/valid/APF0000hw0.jpg
# planetfour/valid/APF0000skb.jpg
# planetfour/valid/APF0000bgj.jpg
# planetfour/valid/APF00009sd.jpg
# planetfour/valid/APF0000kyk.jpg
# planetfour/valid/APF00002x0.jpg
# planetfour/valid/APF0000rv2.jpg
# planetfour/valid/APF0000klh.jpg
# planetfour/valid/APF0000nnj.jpg
# planetfour/valid/APF0000bpd.jpg
# planetfour/valid/APF0000hu6.jpg
# planetfour/valid/APF0000irn.jpg
# planetfour/valid/APF0000mlq.jpg
# planetfour/valid/APF0000n0y.jpg
# planetfour/valid/APF0000e2q.jpg
# planetfour/valid/APF00004t6.jpg
# planetfour/valid/APF0000qb5.jpg
# planetfour/valid/APF0000pjp.jpg
# planetfour/valid/APF0000eos.jpg
# planetfour/valid/APF0000iom.jpg
# planetfour/valid/APF00006qp.jpg
# planetfour/valid/APF00007nk.jpg
# planetfour/valid/APF0000t6a.jpg
# planetfour/valid/APF0000fyg.jpg
# planetfour/valid/APF0000v0c.jpg
# planetfour/valid/APF00001q9.jpg
# planetfour/valid/APF0000r30.jpg
# planetfour/valid/APF0000sgr.jpg
# planetfour/valid/APF000054v.jpg
# planetfour/valid/APF0000np0.jpg
# planetfour/valid/APF0000v8l.jpg
# planetfour/valid/APF0000a3w.jpg
# planetfour/valid/APF000035f.jpg
# planetfour/valid/APF0000lfm.jpg
# planetfour/valid/APF0000hd0.jpg
# planetfour/valid/APF0000mm1.jpg
# planetfour/valid/APF0000njq.jpg
# planetfour/valid/APF0000dwf.jpg
# planetfour/valid/APF000065v.jpg
# planetfour/valid/APF00006ow.jpg
# planetfour/valid/APF0000wuz.jpg
# planetfour/valid/APF00007c8.jpg
# planetfour/valid/APF0000b19.jpg
# planetfour/valid/APF0000hvp.jpg
# planetfour/valid/APF0000522.jpg
# planetfour/valid/APF0000sku.jpg
# planetfour/valid/APF0000907.jpg
# planetfour/valid/APF000021x.jpg
# planetfour/valid/APF00007ju.jpg
# planetfour/valid/APF0000qc4.jpg
# planetfour/valid/APF0000gw3.jpg
# planetfour/valid/APF0000wrw.jpg
# planetfour/valid/APF0000n3f.jpg
# planetfour/valid/APF0000m5s.jpg
# planetfour/valid/APF0000ph4.jpg
# planetfour/valid/APF0000q1m.jpg
# planetfour/valid/APF0000k29.jpg
# planetfour/valid/APF00008lq.jpg
# planetfour/valid/APF0000eke.jpg
# planetfour/valid/APF000047n.jpg
# planetfour/valid/APF00007yl.jpg
# planetfour/valid/APF0000b47.jpg
# planetfour/valid/APF00005rf.jpg
# planetfour/valid/APF0000sge.jpg
# planetfour/valid/APF00000x4.jpg
# planetfour/valid/APF0000r0w.jpg
# planetfour/valid/APF0000cf9.jpg
# planetfour/valid/APF000033s.jpg
# planetfour/valid/APF0000mn7.jpg
# planetfour/valid/APF0000h7h.jpg
# planetfour/valid/APF00000h1.jpg
# planetfour/valid/APF0000i1b.jpg
# planetfour/valid/APF0000x3s.jpg
# planetfour/valid/APF00005de.jpg
# planetfour/valid/APF0000eus.jpg
# planetfour/valid/APF0000ofz.jpg
# planetfour/valid/APF0000bu8.jpg
# planetfour/valid/APF0000wvt.jpg
# planetfour/valid/APF0000put.jpg
# planetfour/valid/APF0000e3m.jpg
# planetfour/valid/APF0000n8z.jpg
# planetfour/valid/APF0000euw.jpg
# planetfour/valid/APF0000co4.jpg
# planetfour/valid/APF0000hgi.jpg
# planetfour/valid/APF000096m.jpg
# planetfour/valid/APF00009up.jpg
# planetfour/valid/APF0000mqa.jpg
# planetfour/valid/APF00009d8.jpg
# planetfour/valid/APF0000kss.jpg
# planetfour/valid/APF00004tr.jpg
# planetfour/valid/APF000035q.jpg
# planetfour/valid/APF0000gih.jpg
# planetfour/valid/APF0000h71.jpg
# planetfour/valid/APF0000dq8.jpg
# planetfour/valid/APF0000k5x.jpg
# planetfour/valid/APF0000cz2.jpg
# planetfour/valid/APF0000ws3.jpg
# planetfour/valid/APF0000d8e.jpg
# planetfour/valid/APF00000wv.jpg
# planetfour/valid/APF00000pi.jpg
# planetfour/valid/APF0000ll8.jpg
# planetfour/valid/APF0000iv9.jpg
# planetfour/valid/APF0000aiy.jpg
# planetfour/valid/APF0000ild.jpg
# planetfour/valid/APF00008x9.jpg
# planetfour/valid/APF0000jni.jpg
# planetfour/valid/APF0000aoh.jpg
# planetfour/valid/APF0000wpj.jpg
# planetfour/valid/APF00002tt.jpg
# planetfour/valid/APF000021p.jpg
# planetfour/valid/APF0000e9v.jpg
# planetfour/valid/APF0000awg.jpg
# planetfour/valid/APF0000l06.jpg
# planetfour/valid/APF00007g6.jpg
# planetfour/valid/APF0000tal.jpg
# planetfour/valid/APF0000auw.jpg
# planetfour/valid/APF0000w3k.jpg
# planetfour/valid/APF0000b5h.jpg
# planetfour/valid/APF000077b.jpg
# planetfour/valid/APF00000o6.jpg
# planetfour/valid/APF00006wn.jpg
# planetfour/valid/APF0000e8t.jpg
# planetfour/valid/APF0000fuy.jpg
# planetfour/valid/APF00007se.jpg
# planetfour/valid/APF0000mnk.jpg
# planetfour/valid/APF0000k9x.jpg
# planetfour/valid/APF0000p09.jpg
# planetfour/valid/APF0000cmu.jpg
# planetfour/valid/APF000097a.jpg
# planetfour/valid/APF0000cui.jpg
# planetfour/valid/APF0000gym.jpg
# planetfour/valid/APF0000art.jpg
# planetfour/valid/APF0000r6p.jpg
# planetfour/valid/APF0000p8g.jpg
# planetfour/valid/APF00005k7.jpg
# planetfour/valid/APF0000pm3.jpg
# planetfour/valid/APF0000q97.jpg
# planetfour/valid/APF0000kb1.jpg
# planetfour/valid/APF00009ps.jpg
# planetfour/valid/APF0000swx.jpg
# planetfour/valid/APF0000wwi.jpg
# planetfour/valid/APF000009j.jpg
# planetfour/valid/APF00007no.jpg
# planetfour/valid/APF0000mop.jpg
# planetfour/valid/APF0000wwj.jpg
# planetfour/valid/APF0000puh.jpg
# planetfour/valid/APF0000c94.jpg
# planetfour/valid/APF0000kf4.jpg
# planetfour/valid/APF0000943.jpg
# planetfour/valid/APF000087p.jpg
# planetfour/valid/APF00009fn.jpg
# planetfour/valid/APF0000aal.jpg
# planetfour/valid/APF0000quj.jpg
# planetfour/valid/APF0000rly.jpg
# planetfour/valid/APF0000p8w.jpg
# planetfour/valid/APF0000fit.jpg
# planetfour/valid/APF0000i8y.jpg
# planetfour/valid/APF00005p0.jpg
# planetfour/valid/APF00006is.jpg
# planetfour/valid/APF0000ws4.jpg
# planetfour/valid/APF0000wlf.jpg
# planetfour/valid/APF00005gw.jpg
# planetfour/valid/APF0000kuf.jpg
# planetfour/valid/APF0000ndj.jpg
# planetfour/valid/APF0000qc7.jpg
# planetfour/valid/APF0000r3u.jpg
# planetfour/valid/APF0000n5t.jpg
# planetfour/valid/APF00003i3.jpg
# planetfour/valid/APF0000aaa.jpg
# planetfour/valid/APF0000pr1.jpg
# planetfour/valid/APF00009rp.jpg
# planetfour/valid/APF0000bik.jpg
# planetfour/valid/APF00009wh.jpg
# planetfour/valid/APF0000wfi.jpg
# planetfour/valid/APF0000ghc.jpg
# planetfour/valid/APF0000dbz.jpg
# planetfour/valid/APF00008y8.jpg
# planetfour/valid/APF0000py9.jpg
# planetfour/valid/APF0000bsy.jpg
# planetfour/valid/APF0000h4b.jpg
# planetfour/valid/APF00008n9.jpg
# planetfour/valid/APF0000tmw.jpg
# planetfour/valid/APF00009ai.jpg
# planetfour/valid/APF0000njr.jpg
# planetfour/valid/APF0000pf1.jpg
# planetfour/valid/APF0000b6c.jpg
# planetfour/valid/APF0000kto.jpg
# planetfour/valid/APF0000nsy.jpg
# planetfour/valid/APF0000gr1.jpg
# planetfour/valid/APF0000tkb.jpg
# planetfour/valid/APF0000mv5.jpg
# planetfour/valid/APF0000c35.jpg
# planetfour/valid/APF0000mka.jpg
# planetfour/valid/APF0000jr1.jpg
# planetfour/valid/APF0000evm.jpg
# planetfour/valid/APF0000fev.jpg
# planetfour/valid/APF00003wg.jpg
# planetfour/valid/APF0000i1y.jpg
# planetfour/valid/APF00005wm.jpg
# planetfour/valid/APF00000tc.jpg
# planetfour/valid/APF00009xs.jpg
# planetfour/valid/APF0000w9q.jpg
# planetfour/valid/APF0000vec.jpg
# planetfour/valid/APF0000axp.jpg
# planetfour/valid/APF0000sii.jpg
# planetfour/valid/APF0000avg.jpg
# planetfour/valid/APF00009yx.jpg
# planetfour/valid/APF0000w04.jpg
# planetfour/valid/APF00005y9.jpg
# planetfour/valid/APF00006bg.jpg
# planetfour/valid/APF00001rc.jpg
# planetfour/valid/APF00005el.jpg
# planetfour/valid/APF0000kny.jpg
# planetfour/valid/APF0000e27.jpg
# planetfour/valid/APF0000czo.jpg
# planetfour/valid/APF0000p6b.jpg
# planetfour/valid/APF000038z.jpg
# planetfour/valid/APF0000k2o.jpg
# planetfour/valid/APF00009k8.jpg
# planetfour/valid/APF0000g29.jpg
# planetfour/valid/APF0000fsv.jpg
# planetfour/valid/APF0000b5p.jpg
# planetfour/valid/APF000032p.jpg
# planetfour/valid/APF0000dv9.jpg
# planetfour/valid/APF0000iko.jpg
# planetfour/valid/APF0000b1k.jpg
# planetfour/valid/APF0000nep.jpg
# planetfour/valid/APF0000kg5.jpg
# planetfour/valid/APF00007p9.jpg
# planetfour/valid/APF0000uiv.jpg
# planetfour/valid/APF000003p.jpg
# planetfour/valid/APF00007l4.jpg
# planetfour/valid/APF00008u5.jpg
# planetfour/valid/APF0000gh3.jpg
# planetfour/valid/APF0000mnt.jpg
# planetfour/valid/APF000001m.jpg
# planetfour/valid/APF0000mq7.jpg
# planetfour/valid/APF0000g1b.jpg
# planetfour/valid/APF00001l7.jpg
# planetfour/valid/APF0000g68.jpg
# planetfour/valid/APF00007k1.jpg
# planetfour/valid/APF0000tde.jpg
# planetfour/valid/APF000092c.jpg
# planetfour/valid/APF0000r3o.jpg
# planetfour/valid/APF00009gf.jpg
# planetfour/valid/APF0000jw8.jpg
# planetfour/valid/APF0000t4b.jpg
# planetfour/valid/APF00007fn.jpg
# planetfour/valid/APF0000ne3.jpg
# planetfour/valid/APF00005qk.jpg
# planetfour/valid/APF0000tim.jpg
# planetfour/valid/APF0000r3e.jpg
# planetfour/valid/APF0000mj9.jpg
# planetfour/valid/APF0000di5.jpg
# planetfour/valid/APF0000co3.jpg
# planetfour/valid/APF0000an7.jpg
# planetfour/valid/APF00005dh.jpg
# planetfour/valid/APF0000nnc.jpg
# planetfour/valid/APF0000hax.jpg
# planetfour/valid/APF00009vp.jpg
# planetfour/valid/APF0000t8p.jpg
# planetfour/valid/APF00009pr.jpg
# planetfour/valid/APF00002c5.jpg
# planetfour/valid/APF0000ga7.jpg
# planetfour/valid/APF0000juc.jpg
# planetfour/valid/APF0000wgt.jpg
# planetfour/valid/APF0000wr3.jpg
# planetfour/valid/APF0000bmo.jpg
# planetfour/valid/APF000022j.jpg
# planetfour/valid/APF0000od8.jpg
# planetfour/valid/APF0000qwu.jpg
# planetfour/valid/APF000004z.jpg
# planetfour/valid/APF00000hd.jpg
# planetfour/valid/APF00007xh.jpg
# planetfour/valid/APF0000nun.jpg
# planetfour/valid/APF0000isi.jpg
# planetfour/valid/APF0000k47.jpg
# planetfour/valid/APF0000ip7.jpg
# planetfour/valid/APF0000qop.jpg
# planetfour/valid/APF0000tg2.jpg
# planetfour/valid/APF00001fh.jpg
# planetfour/valid/APF0000ksv.jpg
# planetfour/valid/APF00002bv.jpg
# planetfour/valid/APF0000ggq.jpg
# planetfour/valid/APF0000ibn.jpg
# planetfour/valid/APF00006lb.jpg
# planetfour/valid/APF0000so1.jpg
# planetfour/valid/APF0000irf.jpg
# planetfour/valid/APF0000220.jpg
# planetfour/valid/APF0000err.jpg
# planetfour/valid/APF0000ehf.jpg
# planetfour/valid/APF0000fvf.jpg
# planetfour/valid/APF0000kt2.jpg
# planetfour/valid/APF00002fb.jpg
# planetfour/valid/APF000003b.jpg
# planetfour/valid/APF0000hg4.jpg
# planetfour/valid/APF0000vt4.jpg
# planetfour/valid/APF0000vwa.jpg
# planetfour/valid/APF0000to6.jpg
# planetfour/valid/APF00002dr.jpg
# planetfour/valid/APF0000tl6.jpg
# planetfour/valid/APF0000koe.jpg
# planetfour/valid/APF0000p6i.jpg
# planetfour/valid/APF0000fax.jpg
# planetfour/valid/APF0000ity.jpg
# planetfour/valid/APF00003g6.jpg
# planetfour/valid/APF0000ahj.jpg
# planetfour/valid/APF0000kxu.jpg
# planetfour/valid/APF0000tap.jpg
# planetfour/valid/APF00007mo.jpg
# planetfour/valid/APF0000ak5.jpg
# planetfour/valid/APF00001f5.jpg
# planetfour/valid/APF0000ky6.jpg
# planetfour/valid/APF0000hri.jpg
# planetfour/valid/APF00003ig.jpg
# planetfour/valid/APF0000q3y.jpg
# planetfour/valid/APF000008w.jpg
# planetfour/valid/APF0000ka9.jpg
# planetfour/valid/APF0000vbm.jpg
# planetfour/valid/APF0000gx7.jpg
# planetfour/valid/APF0000a40.jpg
# planetfour/valid/APF0000s3n.jpg
# planetfour/valid/APF0000kea.jpg
# planetfour/valid/APF000012k.jpg
# planetfour/valid/APF0000adt.jpg
# planetfour/valid/APF00000xi.jpg
# planetfour/valid/APF00008fs.jpg
# planetfour/valid/APF0000pft.jpg
# planetfour/valid/APF0000q3w.jpg
# planetfour/valid/APF0000p0v.jpg
# planetfour/valid/APF0000rl1.jpg
# planetfour/valid/APF0000ex0.jpg
# planetfour/valid/APF000083d.jpg
# planetfour/valid/APF0000moi.jpg
# planetfour/valid/APF0000udc.jpg
# planetfour/valid/APF00007zy.jpg
# planetfour/valid/APF00006if.jpg
# planetfour/valid/APF00000n2.jpg
# planetfour/valid/APF0000007.jpg
# planetfour/valid/APF0000bf6.jpg
# planetfour/valid/APF0000gsz.jpg
# planetfour/valid/APF0000n99.jpg
# planetfour/valid/APF0000dr0.jpg
# planetfour/valid/APF000049f.jpg
# planetfour/valid/APF0000h14.jpg
# planetfour/valid/APF0000wn8.jpg
# planetfour/valid/APF0000jtl.jpg
# planetfour/valid/APF0000pwa.jpg
# planetfour/valid/APF0000p4n.jpg
# planetfour/valid/APF00001mh.jpg
# planetfour/valid/APF0000w24.jpg
# planetfour/valid/APF00001k4.jpg
# planetfour/valid/APF0000q71.jpg
# planetfour/valid/APF0000r3t.jpg
# planetfour/valid/APF0000gvj.jpg
# planetfour/valid/APF0000cnw.jpg
# planetfour/valid/APF00003n8.jpg
# planetfour/valid/APF0000u4n.jpg
# planetfour/valid/APF0000kjl.jpg
# planetfour/valid/APF00004bo.jpg
# planetfour/valid/APF0000ing.jpg
# planetfour/valid/APF0000jco.jpg
# planetfour/valid/APF0000wb6.jpg
# planetfour/valid/APF0000nhv.jpg
# planetfour/valid/APF0000ouu.jpg
# planetfour/valid/APF0000boa.jpg
# planetfour/valid/APF00007ob.jpg
# planetfour/valid/APF00005x3.jpg
# planetfour/valid/APF000087c.jpg
# planetfour/valid/APF00001dx.jpg
# planetfour/valid/APF0000n29.jpg
# planetfour/valid/APF0000n8r.jpg
# planetfour/valid/APF00009to.jpg
# planetfour/valid/APF0000eux.jpg
# planetfour/valid/APF0000kvk.jpg
# planetfour/valid/APF0000r0o.jpg
# planetfour/valid/APF00008h4.jpg
# planetfour/valid/APF0000j2a.jpg
# planetfour/valid/APF0000t5p.jpg
# planetfour/valid/APF0000vch.jpg
# planetfour/valid/APF0000jez.jpg
# planetfour/valid/APF0000a22.jpg
# planetfour/valid/APF0000tqo.jpg
# planetfour/valid/APF0000jvn.jpg
# planetfour/valid/APF00002wx.jpg
# planetfour/valid/APF0000npg.jpg
# planetfour/valid/APF0000bnx.jpg
# planetfour/valid/APF0000dik.jpg
# planetfour/valid/APF00000r7.jpg
# planetfour/test.csv
# planetfour/train.csv

# %%
# !ls '/content/gdrive/MyDrive/EE514(Data-Analysis-&-Machine-Learning)/data/PlanetFour/split/planetfour'
# Out:
# test  test.csv	train  train.csv  valid  valid.csv

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

import torch
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.models as models
import sklearn.metrics as metrics
import tqdm

from torch.utils.data import DataLoader
from torchvision.datasets.folder import pil_loader
from pathlib import Path
from PIL import Image

from google.colab import drive, files

# %% [markdown]
# Change the device to "cpu" if you want to train on a CPU instead of a GPU.

# %%
device = 'cuda'

# %%
drive.mount("/content/gdrive", force_remount=True)
data_dir = '/content/gdrive/MyDrive/EE514(Data-Analysis-&-Machine-Learning)/data/PlanetFour/split/planetfour'
# Out:
# Mounted at /content/gdrive

# %%
# Print num samples in each set
train_dir = f"{data_dir}/train"
valid_dir = f"{data_dir}/valid"
test_dir = f"{data_dir}/test"

print(f"Training samples: {len(os.listdir(train_dir))}")
print(f"Validation samples: {len(os.listdir(valid_dir))}")
print(f"Test samples: {len(os.listdir(test_dir))}")
# Out:
# Training samples: 23299
# Validation samples: 0
# Test samples: 270

# %% [markdown]
# ## Dataset
#
# Here we define a custom Dataset object for the Planet Four data. You can read more about this in the PyTorch documentation: https://pytorch.org/tutorials/beginner/basics/data_tutorial.html

# %%
class PlanetFourDataset(object):
    def __init__(self, split='train', transform=None, loader=pil_loader):
        super().__init__()
        self.split = split
        self.base_dir = Path(data_dir)
        self.image_dir = f"{self.base_dir}/{self.split}"
        self.labels_file = f"{self.base_dir}/{(split + '.csv')}"
        self.labels_df = pd.read_csv(self.labels_file)
        self.transform = transform
        self.loader = loader
        
    def __getitem__(self, index):
        row = self.labels_df.iloc[index]
        filename = f"{self.image_dir}/{(row.tile_id + '.jpg')}"
        fans = int(row.fans)
        blotches = int(row.blotches)
        image = self.loader(str(filename))
        if self.transform is not None:
            image = self.transform(image)
        return image, torch.tensor([fans, blotches], dtype=torch.float32)
    
    def __len__(self):
        return len(self.labels_df)

# %% [markdown]
# ## Data augmentation
#
# It is standard practice in deep learning to augment the training examples to prevent the network from overfitting. Here I use some standard augmentations such as randomly mirroring the images.

# %%
train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))                  
])

valid_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)) 
])

# %% [markdown]
# ## Data loaders
#
# In PyTorch, the data loaders take care of spinning up threads to load batches of data into memory from the dataset object.

# %%
train_set = PlanetFourDataset('train', transform=train_transform)
valid_set = PlanetFourDataset('valid', transform=train_transform)

train_loader = DataLoader(train_set, batch_size=64, shuffle=True)
valid_loader = DataLoader(valid_set, batch_size=64, shuffle=False)

# %% [markdown]
# ## Load a pretrained model
#
# Here we'll use ResNet50 model that has been pretrained on ImageNet and replace the final layer with a new one suited to our problem.

# %%
model = models.resnet50(pretrained=True)
model.fc = nn.Linear(2048, 2)
model.to(device);
# Out:
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]

# %% [markdown]
# ## Loss
#
# Images can contain fans, blotches, both, or neither. You could treat this as a four class softmax problem, or two binary classification problems. Here I take the latter approach and use a binary cross entropy loss.

# %%
criterion = nn.BCEWithLogitsLoss()

# %% [markdown]
# ## Optimizer
#
# Stochastic gradient descent with momentum

# %%
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9, weight_decay=1e-4)

# %% [markdown]
# ## Training and validation functions

# %%
avg_train_losses = []
avg_valid_losses = []
valid_accuracies = []


def train_for_epoch(optimizer):
    model.train()

    train_losses = []

    for batch, target in tqdm.tqdm(train_loader):

        # data to GPU
        batch = batch.to(device)
        target = target.to(device)

        # reset optimizer
        optimizer.zero_grad()

        # forward pass
        predictions = model(batch)
        #breakpoint()

        # calculate loss
        loss = criterion(predictions, target)

        # backward pass
        loss.backward()

        # parameter update
        optimizer.step()

        # track loss
        train_losses.append(float(loss.item()))

    train_losses = np.array(train_losses)
    return train_losses


def validate():
    model.eval()

    valid_losses = []
    y_true, y_prob = [], []

    with torch.no_grad():
        for batch, target in valid_loader:

            # move data to the device
            batch = batch.to(device)
            target = target.to(device)

            # make predictions
            predictions = model(batch)

            # calculate loss
            loss = criterion(predictions, target)
            
            # logits -> probabilities
            torch.sigmoid_(predictions)

            # track losses and predictions
            valid_losses.append(float(loss.item()))
            y_true.extend(target.cpu().numpy())
            y_prob.extend(predictions.cpu().numpy())
            
    y_true = np.array(y_true)
    y_prob = np.array(y_prob)
    y_pred = y_prob > 0.5
    valid_losses = np.array(valid_losses)

    # calculate validation accuracy from y_true and y_pred
    fan_accuracy = metrics.accuracy_score(y_true[:,0], y_pred[:,0])
    blotch_accuracy = metrics.accuracy_score(y_true[:,1], y_pred[:,1])
    exact_accuracy = np.all(y_true == y_pred, axis=1).mean()

    # calculate the mean validation loss
    valid_loss = valid_losses.mean()

    return valid_loss, fan_accuracy, blotch_accuracy, exact_accuracy


def train(epochs, first_epoch=1):
    for epoch in range(first_epoch, epochs+first_epoch):

        # train
        train_loss = train_for_epoch(optimizer)

        # validation
        valid_loss, fan_accuracy, blotch_accuracy, both_accuracy = validate()
        print(f'[{epoch:02d}] train loss: {train_loss.mean():0.04f}  '
              f'valid loss: {valid_loss:0.04f}  ',
              f'fan acc: {fan_accuracy:0.04f}  ',
              f'blotch acc: {blotch_accuracy:0.04f}  ',
              f'both acc: {both_accuracy:0.04f}'
        )
        
        # update learning curves
        avg_train_losses.append(train_loss.mean())
        avg_valid_losses.append(valid_loss)
        valid_accuracies.append((fan_accuracy, blotch_accuracy, both_accuracy))
        
        # save checkpoint
        #torch.save(model, f'checkpoints/baseline_{epoch:03d}.pkl')

# %% [markdown]
# ## Constant classifier accuracy
#
# Evaluate how accurate would a $f(x) = \text{"most common class"}$ classifier be?

# %%
def constant_clf_accuracy():
    y_true, y_pred = [], []
    with torch.no_grad():
        for _, target in valid_loader:
            y_true.extend(target.cpu().numpy())
            y_pred.extend(np.ones((target.shape[0], 2), dtype=np.float32))
            
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
        
    # calculate validation accuracy from y_true and y_pred
    f = metrics.accuracy_score(y_true[:,0], y_pred[:,0])
    b = metrics.accuracy_score(y_true[:,1], y_pred[:,1])
    t = np.all(y_true == y_pred, axis=1).mean()
    print(f'fan: {f}  blotch: {b}  both: {t}')

# %%
constant_clf_accuracy()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-9c9f94d12ba8> in <module>
# ----> 1 constant_clf_accuracy()
#
# <ipython-input-20-b54d1b0da46f> in constant_clf_accuracy()
#       2     y_true, y_pred = [], []
#       3     with torch.no_grad():
# ----> 4         for _, target in valid_loader:
#       5             y_true.extend(target.cpu().numpy())
#       6             y_pred.extend(np.ones((target.shape[0], 2), dtype=np.float32))
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     679                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     680                 self._reset()  # type: ignore[call-arg]
# --> 681             data = self._next_data()
#     682             self._num_yielded += 1
#     683             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     719     def _next_data(self):
#     720         index = self._next_index()  # may raise StopIteration
# --> 721         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     722         if self._pin_memory:
#     723             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# <ipython-input-13-1fe2d15af2c8> in __getitem__(self, index)
#      15         fans = int(row.fans)
#      16         blotches = int(row.blotches)
# ---> 17         image = self.loader(str(filename))
#      18         if self.transform is not None:
#      19             image = self.transform(image)
#
# /usr/local/lib/python3.8/dist-packages/torchvision/datasets/folder.py in pil_loader(path)
#     245 def pil_loader(path: str) -> Image.Image:
#     246     # open path as file to avoid ResourceWarning (https://github.com/python-pillow/Pillow/issues/835)
# --> 247     with open(path, "rb") as f:
#     248         img = Image.open(f)
#     249         return img.convert("RGB")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/MyDrive/EE514(Data-Analysis-&-Machine-Learning)/data/PlanetFour/split/planetfour/valid/APF0000c95.jpg'

# %% [markdown]
# ## Train the model
# Call the ``train(n)`` function to train for ``n`` epochs.

# %%
train(5)
